# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Write a Pandas program to detect missing values of a given DataFrame.
# Display True or False.

# %%
df = pd.read_csv("q1.txt", sep = " ")
df.isna()
# Out:
#     ord_no  purch_amt  ord_date  customer_id  salesman_id
# 0    False      False     False        False        False
# 1     True      False     False        False        False
# 2    False      False      True        False        False
# 3    False      False     False        False         True
# 4     True      False     False        False        False
# 5    False      False     False        False        False
# 6     True      False     False        False        False
# 7    False      False     False        False         True
# 8    False      False     False        False        False
# 9    False      False     False        False        False
# 10    True      False     False        False        False
# 11   False      False     False        False         True

# %% [markdown]
# 2. Write a Pandas program to identify the column(s) of a given DataFrame which
# have at least one missing value.

# %%
df = pd.read_csv("q2.txt", sep = " ")
filt = df.isna().sum()
filt[filt > 0].index
# Out:
# Index(['ord_no', 'ord_date', 'salesman_id'], dtype='object')

# %% [markdown]
# 3. Write a Pandas program to count the number of missing values in each column of a given DataFrame.

# %%
df = pd.read_csv("q3.txt", sep = " ")
df.isna().sum()
# Out:
# ord_no         4
# purch_amt      0
# ord_date       1
# customer_id    0
# salesman_id    3
# dtype: int64

# %% [markdown]
# 4. Write a Pandas program to find and replace the missing values in a given DataFrame which do not have any valuable information.

# %%
# replace null value by 0

df = pd.read_csv("q4.txt", sep = " ")
df.fillna(0, inplace= True)
df.isna().sum()
# Out:
# ord_no         0
# purch_amt      0
# ord_date       0
# customer_id    0
# salesman_id    0
# dtype: int64

# %% [markdown]
# 5. Write a Pandas program to drop the rows where at least one element is missing in a given DataFrame.

# %%
df = pd.read_csv("q5.txt", sep = " ")
df.dropna(inplace = True, axis = 'index')
df
# Out:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50  2012-10-05         3002       5002.0
# 5  70005.0    2400.60  2012-07-27         3001       5001.0
# 8  70003.0    2480.40  2012-10-10         3003       5003.0
# 9  70012.0     250.45  2012-06-27         3002       5002.0

# %% [markdown]
# 6. Write a Pandas program to drop the columns where at least one element is missing in a given DataFrame.

# %%
df = pd.read_csv("q6.txt", sep = " ")
df.dropna(inplace = True, axis = 'columns')
df
# Out:
#     purch_amt  customer_id
# 0      150.50         3002
# 1      270.65         3001
# 2       65.26         3001
# 3      110.50         3003
# 4      948.50         3002
# 5     2400.60         3001
# 6     5760.00         3001
# 7     1983.43         3004
# 8     2480.40         3003
# 9      250.45         3002
# 10      75.29         3001
# 11    3045.60         3001

# %% [markdown]
# 7. Write a Pandas program to drop the rows where all elements are missing in a given DataFrame.

# %%
df = pd.read_csv("q7.txt", sep = " ")
print("\n", df)

df.dropna(inplace = True, axis = 'index', how = "all")
print("\n", df)
# Out:
#       ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3   70004.0     110.50  2012-08-17       3003.0
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11  70013.0    3045.60  2012-04-25       3001.0
#
#       ord_no  purch_amt    ord_date  customer_id
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3   70004.0     110.50  2012-08-17       3003.0
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11  70013.0    3045.60  2012-04-25       3001.0

# %% [markdown]
# 8. Write a Pandas program to keep the rows with at least 2 NaN values in a given DataFrame.

# %%
df = pd.read_csv("q8.txt", sep = " ")
print("\n", df)

df.dropna(inplace = True, axis = 'index', thresh = 2) # thresh = number of values that should not be null for selection
print("\n", df)
# Out:
#       ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3       NaN        NaN         NaN          NaN
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11      NaN        NaN         NaN          NaN
#
#       ord_no  purch_amt    ord_date  customer_id
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0

# %% [markdown]
# 9. Write a Pandas program to drop those rows from a given DataFrame in which specific columns have missing values.

# %%
df = pd.read_csv("q9.txt", sep = " ")
print("\n", df)

df.dropna(inplace = True, axis = 'index', subset = ["ord_no"]) # Dropping rows with Nan in ord_no
print("\n", df)
# Out:
#       ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3       NaN        NaN         NaN          NaN
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11      NaN        NaN         NaN          NaN
#
#      ord_no  purch_amt    ord_date  customer_id
# 2  70002.0      65.26         NaN       3001.0
# 5  70005.0    2400.60  2012-07-27       3001.0
# 7  70010.0    1983.43  2012-10-10       3004.0
# 8  70003.0    2480.40  2012-10-10       3003.0
# 9  70012.0     250.45  2012-06-27       3002.0

# %% [markdown]
#  10. Write a Pandas program to keep the valid entries of a given DataFrame.

# %%
df = pd.read_csv("q10.txt", sep = " ")
print("\n", df)

# valid entry = entry having no null value
df.dropna(inplace = True, how = "any")
print("\n", df)
# Out:
#       ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3       NaN        NaN         NaN          NaN
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11      NaN        NaN         NaN          NaN
#
#      ord_no  purch_amt    ord_date  customer_id
# 5  70005.0    2400.60  2012-07-27       3001.0
# 7  70010.0    1983.43  2012-10-10       3004.0
# 8  70003.0    2480.40  2012-10-10       3003.0
# 9  70012.0     250.45  2012-06-27       3002.0

# %% [markdown]
# 11. Write a Pandas program to calculate the total number of missing values in a DataFrame.

# %%
df = pd.read_csv("q11.txt", sep = " ")
print("\n", df)

print(f"\nTotal number of missing values in DataFrame: ")
df.isna().sum().sum()
# Out:
#       ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3       NaN        NaN         NaN          NaN
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11      NaN        NaN         NaN          NaN
#
# Total number of missing values in DataFrame:
# 17

# %% [markdown]
# 12. Write a Pandas program to replace NaNs with a single constant value in specified columns in a DataFrame.

# %%
df = pd.read_csv("q12.txt", sep = " ")
print("\n", df)

df['ord_no'] = df.copy()['ord_no'].fillna(-999) # replaceing nan value by -999 in ord_no column
print("\n", df)
# Out:
#       ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3       NaN        NaN         NaN          NaN
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11      NaN        NaN         NaN          NaN
#
#       ord_no  purch_amt    ord_date  customer_id
# 0    -999.0        NaN         NaN          NaN
# 1    -999.0     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3    -999.0        NaN         NaN          NaN
# 4    -999.0     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6    -999.0    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10   -999.0      75.29  2012-08-17       3001.0
# 11   -999.0        NaN         NaN          NaN

# %% [markdown]
# 13. Write a Pandas program to replace NaNs with the value from the previous row or the next row in a given DataFrame.

# %%
df = pd.read_csv("q13.txt", sep = " ")
print("\n", df)

df = df.ffill()
df = df.bfill()
print("\n", df)
# Out:
#       ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
#
#       ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1   70001.0     150.50     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26     20.65  2012-09-10         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003       5001.0
# 4   70004.0     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0     948.50     98.50  2012-07-27         3001       5001.0
# 6   70005.0    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004       5001.0
# 8   70003.0    1983.43     19.43  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10  70012.0      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001       5003.0

# %% [markdown]
# 14. Write a Pandas program to replace NaNs with median or mean of the specified columns in a given DataFrame.

# %%
df = pd.read_csv("q14.txt", sep = " ")
print("\n", df)

df["purch_amt"] = df["purch_amt"].fillna(df["purch_amt"].mean())
print("\n", df)
# Out:
#       ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
#
#       ord_no    purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0   150.500000     10.50  2012-10-05         3002       5002.0
# 1       NaN  1376.614444     20.65  2012-09-10         3001       5003.0
# 2   70002.0    65.260000       NaN         NaN         3001       5001.0
# 3   70004.0   110.500000     11.50  2012-08-17         3003          NaN
# 4       NaN   948.500000     98.50  2012-09-10         3002       5002.0
# 5   70005.0  1376.614444       NaN  2012-07-27         3001       5001.0
# 6       NaN  5760.000000     57.00  2012-09-10         3001       5001.0
# 7   70010.0  1983.430000     19.43  2012-10-10         3004          NaN
# 8   70003.0  1376.614444       NaN  2012-10-10         3003       5003.0
# 9   70012.0   250.450000     25.45  2012-06-27         3002       5002.0
# 10      NaN    75.290000     75.29  2012-08-17         3001       5003.0
# 11  70013.0  3045.600000     35.60  2012-04-25         3001          NaN

# %% [markdown]
# 15. Write a Pandas program to interpolate the missing values using the Linear Interpolation method in a given DataFrame.
#
# From Wikipedia, in mathematics, linear interpolation is a method of curve fitting using linear polynomials to construct new data points within the range of a
# discrete set of known data points.

# %%
df = pd.read_csv("q15.txt", sep = " ")
print("\n", df)

df = df.interpolate(method = 'linear')
print("\n", df)
# Out:
#       ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
#
#       ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50    10.500  2012-10-05         3002       5002.0
# 1   70001.5     107.88    20.650  2012-09-10         3001       5003.0
# 2   70002.0      65.26    16.075         NaN         3001       5001.0
# 3   70004.0     110.50    11.500  2012-08-17         3003       5001.5
# 4   70004.5     948.50    98.500  2012-09-10         3002       5002.0
# 5   70005.0    3354.25    77.750  2012-07-27         3001       5001.0
# 6   70007.5    5760.00    57.000  2012-09-10         3001       5001.0
# 7   70010.0    1983.43    19.430  2012-10-10         3004       5002.0
# 8   70003.0    1116.94    22.440  2012-10-10         3003       5003.0
# 9   70012.0     250.45    25.450  2012-06-27         3002       5002.0
# 10  70012.5      75.29    75.290  2012-08-17         3001       5003.0
# 11  70013.0    3045.60    35.600  2012-04-25         3001       5003.0
# <ipython-input-47-631f6cb638b8>:4: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df = df.interpolate(method = 'linear')

# %% [markdown]
# 16. Write a Pandas program to count the number of missing values of a specified column in a given DataFrame.

# %%
df = pd.read_csv("q16.txt", sep = " ")
print("\n", df)

print(f"\n\nNull values in purch_amt column: {df.isna()['purch_amt'].sum()}")
# Out:
#       ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
#
#
# Null values in purch_amt column: 3

# %% [markdown]
# 17. Write a Pandas program to count the missing values in a given DataFrame.

# %%
df = pd.read_csv("q17.txt", sep = " ")
print("\n", df)

print(f"\n\nNull values in entire dataframe: {df.isna().sum().sum()}")
# Out:
#       ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
#
#
# Null values in entire dataframe: 14

# %% [markdown]
# 18. Write a Pandas program to find the Indexes of missing values in a given DataFrame.

# %%
df = pd.read_csv("q18.txt", sep=" ")
print("\n", df)

ndf = df.isna().T.sum()
print(f"\nIndices having at least 1 Null values: {ndf[ndf > 0].index.tolist()}")
# Out:
#       ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
#
# Indices having at least 1 Null values: [1, 2, 3, 4, 5, 6, 7, 8, 10, 11]

# %% [markdown]
# 19. Write a Pandas program to replace the missing values with the most frequent values present in each column of a given DataFrame.

# %%
df = pd.read_csv("q19.txt", sep = " ")
print("\n", df)

df["salesman_id"] = df["salesman_id"].fillna(df["salesman_id"].mode()[0])
print("\n", df)
# Out:
#      #   ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# #   0  70001.0     150.50     10.50  2012-10-05         3002       5002.0
# #   1      NaN        NaN     20.65  2012-09-10         3001       5003.0
# #   2  70002.0      65.26       NaN         NaN         3001       5001.0
# #   3  70004.0     110.50     11.50  2012-08-17         3003          NaN
# #   4      NaN     948.50     98.50  2012-09-10         3002       5002.0
# #   5  70005.0        NaN       NaN  2012-07-27         3001       5001.0
# #   6      NaN    5760.00     57.00  2012-09-10         3001       5001.0
# #   7  70010.0    1983.43     19.43  2012-10-10         3004          NaN
# #   8  70003.0        NaN       NaN  2012-10-10         3003       5003.0
# #   9  70012.0     250.45     25.45  2012-06-27         3002       5002.0
# #  10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# #  11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
#
#      #   ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# #   0  70001.0     150.50     10.50  2012-10-05         3002       5002.0
# #   1      NaN        NaN     20.65  2012-09-10         3001       5003.0
# #   2  70002.0      65.26       NaN         NaN         3001       5001.0
# #   3  70004.0     110.50     11.50  2012-08-17         3003       5001.0
# #   4      NaN     948.50     98.50  2012-09-10         3002       5002.0
# #   5  70005.0        NaN       NaN  2012-07-27         3001       5001.0
# #   6      NaN    5760.00     57.00  2012-09-10         3001       5001.0
# #   7  70010.0    1983.43     19.43  2012-10-10         3004       5001.0
# #   8  70003.0        NaN       NaN  2012-10-10         3003       5003.0
# #   9  70012.0     250.45     25.45  2012-06-27         3002       5002.0
# #  10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# #  11  70013.0    3045.60     35.60  2012-04-25         3001       5001.0

# %% [markdown]
# 20. Write a Pandas program to create a hitmap for more information about the distribution of missing values in a given DataFrame.

# %%
import seaborn as sns
df = pd.read_csv("q20.txt", sep = " ")
missing_values=  df.isnull().astype(int)
sns.heatmap(missing_values, cmap = "viridis", cbar = False, yticklabels = False)
plt.show()

# %%
# 1. Write a Pandas program to detect missing values of a given DataFrame.
# Display True or False.
# ord_no purch_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 2012-10-05 3002 5002.0
# 1 NaN 270.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN 3001 5001.0
# 3 70004.0 110.50 2012-08-17 3003 NaN
# 4 NaN 948.50 2012-09-10 3002 5002.0
# 5 70005.0 2400.60 2012-07-27 3001 5001.0
# 6 NaN 5760.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 2012-10-10 3004 NaN
# 8 70003.0 2480.40 2012-10-10 3003 5003.0
# 9 70012.0 250.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 2012-04-25 3001 NaN


# 2. Write a Pandas program to identify the column(s) of a given DataFrame which
# have at least one missing value.
# Test Data:
# ord_no purch_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 2012-10-05 3002 5002.0
# 1 NaN 270.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN 3001 5001.0
# 3 70004.0 110.50 2012-08-17 3003 NaN
# 4 NaN 948.50 2012-09-10 3002 5002.0
# 5 70005.0 2400.60 2012-07-27 3001 5001.0
# 6 NaN 5760.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 2012-10-10 3004 NaN
# 8 70003.0 2480.40 2012-10-10 3003 5003.0
# 9 70012.0 250.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 2012-04-25 3001 NaN

# 3. Write a Pandas program to count the number of missing values in each
# column of a given DataFrame.
# Test Data:
# ord_no purch_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 2012-10-05 3002 5002.0
# 1 NaN 270.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN 3001 5001.0
# 3 70004.0 110.50 2012-08-17 3003 NaN
# 4 NaN 948.50 2012-09-10 3002 5002.0
# 5 70005.0 2400.60 2012-07-27 3001 5001.0
# 6 NaN 5760.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 2012-10-10 3004 NaN
# 8 70003.0 2480.40 2012-10-10 3003 5003.0
# 9 70012.0 250.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 2012-04-25 3001 NaN

# 4. Write a Pandas program to find and replace the missing values in a given
# DataFrame which do not have any valuable information.
# Test Data:
# ord_no purch_amt ord_date customer_id salesman_id
# 0 70001 150.5 ? 3002 5002
# 1 NaN 270.65 2012-09-10 3001 5003
# 2 70002 65.26 NaN 3001 ?
# 3 70004 110.5 2012-08-17 3003 5001
# 4 NaN 948.5 2012-09-10 3002 NaN
# 5 70005 2400.6 2012-07-27 3001 5002
# 6 -- 5760 2012-09-10 3001 5001
# 7 70010 ? 2012-10-10 3004 ?
# 8 70003 12.43 2012-10-10 -- 5003
# 9 70012 2480.4 2012-06-27 3002 5002
# 10 NaN 250.45 2012-08-17 3001 5003
# 11 70013 3045.6 2012-04-25 3001 --

# 5. Write a Pandas program to drop the rows where at least one element is
# missing in a given DataFrame.
# Test Data:
# ord_no purch_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 2012-10-05 3002 5002.0
# 1 NaN 270.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN 3001 5001.0
# 3 70004.0 110.50 2012-08-17 3003 NaN
# 4 NaN 948.50 2012-09-10 3002 5002.0
# 5 70005.0 2400.60 2012-07-27 3001 5001.0
# 6 NaN 5760.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 2012-10-10 3004 NaN
# 8 70003.0 2480.40 2012-10-10 3003 5003.0
# 9 70012.0 250.45 2012-06-27 3002 5002.0

# 10 NaN 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 2012-04-25 3001 NaN

# 6. Write a Pandas program to drop the columns where at least one element is
# missing in a given DataFrame.
# Test Data:
# ord_no purch_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 2012-10-05 3002 5002.0
# 1 NaN 270.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN 3001 5001.0
# 3 70004.0 110.50 2012-08-17 3003 NaN
# 4 NaN 948.50 2012-09-10 3002 5002.0
# 5 70005.0 2400.60 2012-07-27 3001 5001.0
# 6 NaN 5760.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 2012-10-10 3004 NaN
# 8 70003.0 2480.40 2012-10-10 3003 5003.0
# 9 70012.0 250.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 2012-04-25 3001 NaN

# 7. Write a Pandas program to drop the rows where all elements are missing in a
# given DataFrame.
# Test Data:
# ord_no purch_amt ord_date customer_id
# 0 NaN NaN NaN NaN
# 1 NaN 270.65 2012-09-10 3001.0
# 2 70002.0 65.26 NaN 3001.0
# 3 70004.0 110.50 2012-08-17 3003.0
# 4 NaN 948.50 2012-09-10 3002.0
# 5 70005.0 2400.60 2012-07-27 3001.0
# 6 NaN 5760.00 2012-09-10 3001.0
# 7 70010.0 1983.43 2012-10-10 3004.0
# 8 70003.0 2480.40 2012-10-10 3003.0
# 9 70012.0 250.45 2012-06-27 3002.0
# 10 NaN 75.29 2012-08-17 3001.0
# 11 70013.0 3045.60 2012-04-25 3001.0

# 8. Write a Pandas program to keep the rows with at least 2 NaN values in a given
# DataFrame.
# Test Data:
# ord_no purch_amt ord_date customer_id
# 0 NaN NaN NaN NaN
# 1 NaN 270.65 2012-09-10 3001.0
# 2 70002.0 65.26 NaN 3001.0
# 3 NaN NaN NaN NaN
# 4 NaN 948.50 2012-09-10 3002.0
# 5 70005.0 2400.60 2012-07-27 3001.0
# 6 NaN 5760.00 2012-09-10 3001.0
# 7 70010.0 1983.43 2012-10-10 3004.0
# 8 70003.0 2480.40 2012-10-10 3003.0
# 9 70012.0 250.45 2012-06-27 3002.0
# 10 NaN 75.29 2012-08-17 3001.0
# 11 NaN NaN NaN NaN

# 9. Write a Pandas program to drop those rows from a given DataFrame in which
# specific columns have missing values.
# Test Data:
# ord_no purch_amt ord_date customer_id
# 0 NaN NaN NaN NaN
# 1 NaN 270.65 2012-09-10 3001.0
# 2 70002.0 65.26 NaN 3001.0
# 3 NaN NaN NaN NaN
# 4 NaN 948.50 2012-09-10 3002.0
# 5 70005.0 2400.60 2012-07-27 3001.0
# 6 NaN 5760.00 2012-09-10 3001.0
# 7 70010.0 1983.43 2012-10-10 3004.0
# 8 70003.0 2480.40 2012-10-10 3003.0
# 9 70012.0 250.45 2012-06-27 3002.0
# 10 NaN 75.29 2012-08-17 3001.0
# 11 NaN NaN NaN NaN

# 10. Write a Pandas program to keep the valid entries of a given DataFrame.
# Test Data:
# ord_no purch_amt ord_date customer_id
# 0 NaN NaN NaN NaN
# 1 NaN 270.65 2012-09-10 3001.0
# 2 70002.0 65.26 NaN 3001.0
# 3 NaN NaN NaN NaN
# 4 NaN 948.50 2012-09-10 3002.0
# 5 70005.0 2400.60 2012-07-27 3001.0
# 6 NaN 5760.00 2012-09-10 3001.0
# 7 70010.0 1983.43 2012-10-10 3004.0
# 8 70003.0 2480.40 2012-10-10 3003.0
# 9 70012.0 250.45 2012-06-27 3002.0
# 10 NaN 75.29 2012-08-17 3001.0
# 11 NaN NaN NaN NaN

# 11. Write a Pandas program to calculate the total number of missing values in a
# DataFrame.
# Test Data:
# ord_no purch_amt ord_date customer_id
# 0 NaN NaN NaN NaN
# 1 NaN 270.65 2012-09-10 3001.0
# 2 70002.0 65.26 NaN 3001.0
# 3 NaN NaN NaN NaN
# 4 NaN 948.50 2012-09-10 3002.0
# 5 70005.0 2400.60 2012-07-27 3001.0
# 6 NaN 5760.00 2012-09-10 3001.0
# 7 70010.0 1983.43 2012-10-10 3004.0
# 8 70003.0 2480.40 2012-10-10 3003.0
# 9 70012.0 250.45 2012-06-27 3002.0
# 10 NaN 75.29 2012-08-17 3001.0
# 11 NaN NaN NaN NaN

# 12. Write a Pandas program to replace NaNs with a single constant value in
# specified columns in a DataFrame.
# Test Data:
# ord_no purch_amt ord_date customer_id
# 0 NaN NaN NaN NaN
# 1 NaN 270.65 2012-09-10 3001.0
# 2 70002.0 65.26 NaN 3001.0
# 3 NaN NaN NaN NaN
# 4 NaN 948.50 2012-09-10 3002.0
# 5 70005.0 2400.60 2012-07-27 3001.0
# 6 NaN 5760.00 2012-09-10 3001.0
# 7 70010.0 1983.43 2012-10-10 3004.0
# 8 70003.0 2480.40 2012-10-10 3003.0
# 9 70012.0 250.45 2012-06-27 3002.0

# 10 NaN 75.29 2012-08-17 3001.0
# 11 NaN NaN NaN NaN

# 13. Write a Pandas program to replace NaNs with the value from the previous
# row or the next row in a given DataFrame.
# Test Data:
# ord_no purch_amt sale_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 10.50 2012-10-05 3002 5002.0
# 1 NaN NaN 20.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN NaN 3001 5001.0
# 3 70004.0 110.50 11.50 2012-08-17 3003 NaN
# 4 NaN 948.50 98.50 2012-09-10 3002 5002.0
# 5 70005.0 NaN NaN 2012-07-27 3001 5001.0
# 6 NaN 5760.00 57.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 19.43 2012-10-10 3004 NaN
# 8 70003.0 NaN NaN 2012-10-10 3003 5003.0
# 9 70012.0 250.45 25.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 35.60 2012-04-25 3001 NaN

# 14. Write a Pandas program to replace NaNs with median or mean of the
# specified columns in a given DataFrame.
# Test Data:
# ord_no purch_amt sale_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 10.50 2012-10-05 3002 5002.0
# 1 NaN NaN 20.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN NaN 3001 5001.0
# 3 70004.0 110.50 11.50 2012-08-17 3003 NaN
# 4 NaN 948.50 98.50 2012-09-10 3002 5002.0
# 5 70005.0 NaN NaN 2012-07-27 3001 5001.0
# 6 NaN 5760.00 57.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 19.43 2012-10-10 3004 NaN
# 8 70003.0 NaN NaN 2012-10-10 3003 5003.0
# 9 70012.0 250.45 25.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 35.60 2012-04-25 3001 NaN


# 15. Write a Pandas program to interpolate the missing values using the Linear
# Interpolation method in a given DataFrame.
# From Wikipedia, in mathematics, linear interpolation is a method of curve fitting
# using linear polynomials to construct new data points within the range of a
# discrete set of known data points.
# Test Data:
# ord_no purch_amt sale_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 10.50 2012-10-05 3002 5002.0
# 1 NaN NaN 20.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN NaN 3001 5001.0
# 3 70004.0 110.50 11.50 2012-08-17 3003 NaN
# 4 NaN 948.50 98.50 2012-09-10 3002 5002.0
# 5 70005.0 NaN NaN 2012-07-27 3001 5001.0
# 6 NaN 5760.00 57.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 19.43 2012-10-10 3004 NaN
# 8 70003.0 NaN NaN 2012-10-10 3003 5003.0
# 9 70012.0 250.45 25.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 35.60 2012-04-25 3001 NaN

# 16. Write a Pandas program to count the number of missing values of a specified
# column in a given DataFrame.
# Test Data:
# ord_no purch_amt sale_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 10.50 2012-10-05 3002 5002.0
# 1 NaN NaN 20.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN NaN 3001 5001.0
# 3 70004.0 110.50 11.50 2012-08-17 3003 NaN
# 4 NaN 948.50 98.50 2012-09-10 3002 5002.0
# 5 70005.0 NaN NaN 2012-07-27 3001 5001.0
# 6 NaN 5760.00 57.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 19.43 2012-10-10 3004 NaN
# 8 70003.0 NaN NaN 2012-10-10 3003 5003.0
# 9 70012.0 250.45 25.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 35.60 2012-04-25 3001 NaN

# 17. Write a Pandas program to count the missing values in a given DataFrame.
# Test Data:

# ord_no purch_amt sale_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 10.50 2012-10-05 3002 5002.0
# 1 NaN NaN 20.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN NaN 3001 5001.0
# 3 70004.0 110.50 11.50 2012-08-17 3003 NaN
# 4 NaN 948.50 98.50 2012-09-10 3002 5002.0
# 5 70005.0 NaN NaN 2012-07-27 3001 5001.0
# 6 NaN 5760.00 57.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 19.43 2012-10-10 3004 NaN
# 8 70003.0 NaN NaN 2012-10-10 3003 5003.0
# 9 70012.0 250.45 25.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 35.60 2012-04-25 3001 NaN

# 18. Write a Pandas program to find the Indexes of missing values in a given
# DataFrame.
# Test Data:
# ord_no purch_amt sale_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 10.50 2012-10-05 3002 5002.0
# 1 NaN NaN 20.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN NaN 3001 5001.0
# 3 70004.0 110.50 11.50 2012-08-17 3003 NaN
# 4 NaN 948.50 98.50 2012-09-10 3002 5002.0
# 5 70005.0 NaN NaN 2012-07-27 3001 5001.0
# 6 NaN 5760.00 57.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 19.43 2012-10-10 3004 NaN
# 8 70003.0 NaN NaN 2012-10-10 3003 5003.0
# 9 70012.0 250.45 25.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 35.60 2012-04-25 3001 NaN

# 19. Write a Pandas program to replace the missing values with the most frequent
# values present in each column of a given DataFrame.
# Test Data:
# ord_no purch_amt sale_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 10.50 2012-10-05 3002 5002.0
# 1 NaN NaN 20.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN NaN 3001 5001.0
# 3 70004.0 110.50 11.50 2012-08-17 3003 NaN
# 4 NaN 948.50 98.50 2012-09-10 3002 5002.0
# 5 70005.0 NaN NaN 2012-07-27 3001 5001.0
# 6 NaN 5760.00 57.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 19.43 2012-10-10 3004 NaN
# 8 70003.0 NaN NaN 2012-10-10 3003 5003.0
# 9 70012.0 250.45 25.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 35.60 2012-04-25 3001 NaN

# 20. Write a Pandas program to create a hitmap for more information about the
# distribution of missing values in a given DataFrame.
# Test Data:
# ord_no purch_amt sale_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 10.50 2012-10-05 3002 5002.0
# 1 NaN NaN 20.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN NaN 3001 5001.0
# 3 70004.0 110.50 11.50 2012-08-17 3003 NaN
# 4 NaN 948.50 98.50 2012-09-10 3002 5002.0
# 5 70005.0 NaN NaN 2012-07-27 3001 5001.0
# 6 NaN 5760.00 57.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 19.43 2012-10-10 3004 NaN
# 8 70003.0 NaN NaN 2012-10-10 3003 5003.0
# 9 70012.0 250.45 25.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 35.60 2012-04-25 3001 NaN
