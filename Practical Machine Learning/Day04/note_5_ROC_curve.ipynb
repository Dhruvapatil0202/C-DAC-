# %%
import pandas as pd
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# %%
y_test = [1, 1, 0, 0, 0, 1, 0, 0, 1, 0]
yprob_1 = [.6, .4, .8, .2, .3, .6, .3, .8, .6, .3]
yprob_2 = [.7, .45, .9, .2, .15, .7, .3, .6, .7, .2]
df = pd.DataFrame(data = {
    "y_test" : y_test,
    "yprob_1" : yprob_1,
    "yprob_2" : yprob_2
})
df
# Out:
#    y_test  yprob_1  yprob_2
# 0       1      0.6     0.70
# 1       1      0.4     0.45
# 2       0      0.8     0.90
# 3       0      0.2     0.20
# 4       0      0.3     0.15
# 5       1      0.6     0.70
# 6       0      0.3     0.30
# 7       0      0.8     0.60
# 8       1      0.6     0.70
# 9       0      0.3     0.20
