# %%
import numpy as np

# %%
# Standard Scaling

# %%
a = np.array([100, 121, 144, 169, 196, 225, 256])
b = np.array([20, 22, 24, 26, 28, 30, 32])

# %%
ma, mb = a.mean(), b.mean()
sa, sb = a.std(), b.std()
scl_a = (a - ma) / sa
scl_b = (b - mb) / sb

# %%
scl_a.mean()
# Out:
# 6.344131569286608e-17

# %%
scl_b
# Out:
# array([-1.5, -1. , -0.5,  0. ,  0.5,  1. ,  1.5])

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

# %%
scl_std = StandardScaler()
df = pd.DataFrame({'a': a, 'b':b})
scl_std.fit(df)
# Out:
# StandardScaler()

# %%
scl_std.mean_
# Out:
# array([173.,  26.])

# %%
scl_std.transform(df)
# Out:
# array([[-1.40074144, -1.5       ],
#        [-0.99778842, -1.        ],
#        [-0.55645893, -0.5       ],
#        [-0.07675296,  0.        ],
#        [ 0.44132949,  0.5       ],
#        [ 0.99778842,  1.        ],
#        [ 1.59262383,  1.5       ]])

# %%
# Min Max scaling

# Nearly all algorithms in neural netwroks use Min_Max scaling

# %%
a = np.array([100, 121, 144, 169, 196, 225, 256])
b = np.array([20, 22, 24, 26, 28, 30, 32])

# %%
# Manual calculations

min_a, min_b = a.min(), b.min()
max_a, max_b = a.max(), b.max()

a_Scaled = (a - min_a) / (max_a - min_a)
b_Scaled = (b - min_b) / (max_b - min_b)

# %%
a_Scaled, b_Scaled
# Out:
# (array([0.        , 0.13461538, 0.28205128, 0.44230769, 0.61538462,
#         0.80128205, 1.        ]),
#  array([0.        , 0.16666667, 0.33333333, 0.5       , 0.66666667,
#         0.83333333, 1.        ]))
