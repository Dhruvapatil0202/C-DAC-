# %%
import pandas as pd
import numpy as np
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV, KFold
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, confusion_matrix, log_loss, roc_auc_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.decomposition import PCA
from sklearn.svm import SVC

from sklearn.tree import DecisionTreeClassifier, plot_tree

import warnings
warnings.filterwarnings('ignore')

# %%
hr = pd.read_csv("HR_comma_sep.csv")
hr.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.10             0.77               6                   247
# 3                0.92             0.85               5                   259
# 4                0.89             1.00               5                   224
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   5              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# 2     low
# 3     low
# 4     low

# %%
X = hr.drop("left", axis=1)
y = hr["left"]

# %%
# ______________________________________________________________________________________
# Pipeline

# one hot encoder
ohe = OneHotEncoder(
    handle_unknown="ignore", 
    sparse_output=False, 
    drop='first'
).set_output(transform='pandas')

trans_ohe = make_column_transformer(
    ('passthrough', make_column_selector(dtype_exclude=object)),
    (ohe, make_column_selector(dtype_include=object)),
    verbose_feature_names_out=False
).set_output(transform='pandas')


# scaler
scl_std = StandardScaler().set_output(transform = "pandas")
scl_mm = MinMaxScaler().set_output(transform = "pandas")


# model
dtc = DecisionTreeClassifier(
    random_state = 24,
    # max_depth = 4
)


pipe_pca = Pipeline([("OHE", trans_ohe), ("SCL", scl_std), ("DTC", dtc)])


# _____________________________________________________________________________________
# GCV

params = {
    "DTC__max_depth" : [None, 4, 6],
    "DTC__min_samples_leaf" : [1, 10, 25, 50],
    "DTC__min_samples_split" : [2, 10, 25, 50],
}

kfolds = StratifiedKFold(n_splits = 5, 
                        random_state = 24, 
                        shuffle = True)

gcv = GridSearchCV(pipe_pca,
                  param_grid = params,
                  scoring = "roc_auc",
                  cv = kfolds,
                  verbose = 3)

gcv.fit(X, y)
# gcv.fit(x, y)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5] END DTC__max_depth=None, DTC__min_samples_leaf=1, DTC__min_samples_split=2;, score=0.977 total time=   0.0s
# [CV 2/5] END DTC__max_depth=None, DTC__min_samples_leaf=1, DTC__min_samples_split=2;, score=0.972 total time=   0.0s
# [CV 3/5] END DTC__max_depth=None, DTC__min_samples_leaf=1, DTC__min_samples_split=2;, score=0.973 total time=   0.0s
# [CV 4/5] END DTC__max_depth=None, DTC__min_samples_leaf=1, DTC__min_samples_split=2;, score=0.976 total time=   0.0s
# [CV 5/5] END DTC__max_depth=None, DTC__min_samples_leaf=1, DTC__min_samples_split=2;, score=0.978 total time=   0.0s
# [CV 1/5] END DTC__max_depth=None, DTC__min_samples_leaf=1, DTC__min_samples_split=10;, score=0.985 total time=   0.0s
# [CV 2/5] END DTC__max_depth=None, DTC__min_samples_leaf=1, DTC__min_samples_split=10;, score=0.980 total time=   0.0s
# [CV 3/5] END DTC__max_depth=None, DTC__min_samples_leaf=1, DTC__min_samples_split=10;, score=0.980 total time=   0.0s
# [CV 4/5] END DTC__max_depth=None, DTC__min_samples_leaf=1, DTC__min_samples_split=10;, score=0.986 total time=   0.0s
# [CV 5/5] END DTC__max_depth=None, DTC__min_samples_leaf=1, DTC__min_samples_split=10;, score=0.983 total time=   0.0s
# [CV 1/5] END DTC__max_depth=None, DTC__min_samples_leaf=1, DTC__min_samples_split=25;, score=0.986 total time=   0.0s
# [CV 2/5] END DTC__max_depth=None, DTC__min_samples_leaf=1, DTC__min_samples_split=25;, score=0.984 total time=   0.0s
# [CV 3/5] END DTC__max_depth=None, DTC__min_samples_leaf=1, DTC__min_samples_split=25;, score=0.984 total time=   0.0s
# [CV 4/5] END DTC__max_depth=None, DTC__min_samples_leaf=1, DTC__min_samples_split=25;, score=0.986 total time=   0.0s
# [CV 5/5] END DTC__max_depth=None, DTC__min_samples_leaf=1, DTC__min_samples_split=25;, score=0.984 total time=   0.0s
# [CV 1/5] END DTC__max_depth=None, DTC__min_samples_leaf=1, DTC__min_samples_split=50;, score=0.987 total time=   0.0s
# [CV 2/5] END DTC__max_depth=None, DTC__min_samples_leaf=1, DTC__min_samples_split=50;, score=0.984 total time=   0.0s
# [CV 3/5] END DTC__max_depth=None, DTC__min_samples_leaf=1, DTC__min_samples_split=50;, score=0.986 total time=   0.0s
# [CV 4/5] END DTC__max_depth=None, DTC__min_samples_leaf=1, DTC__min_samples_split=50;, score=0.986 total time=   0.0s
# [CV 5/5] END DTC__max_depth=None, DTC__min_samples_leaf=1, DTC__min_samples_split=50;, score=0.985 total time=   0.0s
# [CV 1/5] END DTC__max_depth=None, DTC__min_samples_leaf=10, DTC__min_samples_split=2;, score=0.988 total time=   0.0s
# [CV 2/5] END DTC__max_depth=None, DTC__min_samples_leaf=10, DTC__min_samples_split=2;, score=0.983 total time=   0.0s
# [CV 3/5] END DTC__max_depth=None, DTC__min_samples_leaf=10, DTC__min_samples_split=2;, score=0.987 total time=   0.0s
# [CV 4/5] END DTC__max_depth=None, DTC__min_samples_leaf=10, DTC__min_samples_split=2;, score=0.987 total time=   0.0s
# [CV 5/5] END DTC__max_depth=None, DTC__min_samples_leaf=10, DTC__min_samples_split=2;, score=0.985 total time=   0.0s
# [CV 1/5] END DTC__max_depth=None, DTC__min_samples_leaf=10, DTC__min_samples_split=10;, score=0.988 total time=   0.0s
# [CV 2/5] END DTC__max_depth=None, DTC__min_samples_leaf=10, DTC__min_samples_split=10;, score=0.983 total time=   0.0s
# [CV 3/5] END DTC__max_depth=None, DTC__min_samples_leaf=10, DTC__min_samples_split=10;, score=0.987 total time=   0.0s
# [CV 4/5] END DTC__max_depth=None, DTC__min_samples_leaf=10, DTC__min_samples_split=10;, score=0.987 total time=   0.0s
# [CV 5/5] END DTC__max_depth=None, DTC__min_samples_leaf=10, DTC__min_samples_split=10;, score=0.985 total time=   0.0s
# [CV 1/5] END DTC__max_depth=None, DTC__min_samples_leaf=10, DTC__min_samples_split=25;, score=0.988 total time=   0.0s
# [CV 2/5] END DTC__max_depth=None, DTC__min_samples_leaf=10, DTC__min_samples_split=25;, score=0.983 total time=   0.0s
# [CV 3/5] END DTC__max_depth=None, DTC__min_samples_leaf=10, DTC__min_samples_split=25;, score=0.988 total time=   0.0s
# [CV 4/5] END DTC__max_depth=None, DTC__min_samples_leaf=10, DTC__min_samples_split=25;, score=0.986 total time=   0.0s
# [CV 5/5] END DTC__max_depth=None, DTC__min_samples_leaf=10, DTC__min_samples_split=25;, score=0.985 total time=   0.0s
# [CV 1/5] END DTC__max_depth=None, DTC__min_samples_leaf=10, DTC__min_samples_split=50;, score=0.988 total time=   0.0s
# [CV 2/5] END DTC__max_depth=None, DTC__min_samples_leaf=10, DTC__min_samples_split=50;, score=0.984 total time=   0.0s
# [CV 3/5] END DTC__max_depth=None, DTC__min_samples_leaf=10, DTC__min_samples_split=50;, score=0.987 total time=   0.0s
# [CV 4/5] END DTC__max_depth=None, DTC__min_samples_leaf=10, DTC__min_samples_split=50;, score=0.986 total time=   0.0s
# [CV 5/5] END DTC__max_depth=None, DTC__min_samples_leaf=10, DTC__min_samples_split=50;, score=0.986 total time=   0.0s
# [CV 1/5] END DTC__max_depth=None, DTC__min_samples_leaf=25, DTC__min_samples_split=2;, score=0.987 total time=   0.0s
# [CV 2/5] END DTC__max_depth=None, DTC__min_samples_leaf=25, DTC__min_samples_split=2;, score=0.988 total time=   0.0s
# [CV 3/5] END DTC__max_depth=None, DTC__min_samples_leaf=25, DTC__min_samples_split=2;, score=0.982 total time=   0.0s
# [CV 4/5] END DTC__max_depth=None, DTC__min_samples_leaf=25, DTC__min_samples_split=2;, score=0.984 total time=   0.0s
# [CV 5/5] END DTC__max_depth=None, DTC__min_samples_leaf=25, DTC__min_samples_split=2;, score=0.982 total time=   0.0s
# [CV 1/5] END DTC__max_depth=None, DTC__min_samples_leaf=25, DTC__min_samples_split=10;, score=0.987 total time=   0.0s
# [CV 2/5] END DTC__max_depth=None, DTC__min_samples_leaf=25, DTC__min_samples_split=10;, score=0.988 total time=   0.0s
# [CV 3/5] END DTC__max_depth=None, DTC__min_samples_leaf=25, DTC__min_samples_split=10;, score=0.982 total time=   0.0s
# [CV 4/5] END DTC__max_depth=None, DTC__min_samples_leaf=25, DTC__min_samples_split=10;, score=0.984 total time=   0.0s
# [CV 5/5] END DTC__max_depth=None, DTC__min_samples_leaf=25, DTC__min_samples_split=10;, score=0.982 total time=   0.0s
# [CV 1/5] END DTC__max_depth=None, DTC__min_samples_leaf=25, DTC__min_samples_split=25;, score=0.987 total time=   0.0s
# [CV 2/5] END DTC__max_depth=None, DTC__min_samples_leaf=25, DTC__min_samples_split=25;, score=0.988 total time=   0.0s
# [CV 3/5] END DTC__max_depth=None, DTC__min_samples_leaf=25, DTC__min_samples_split=25;, score=0.982 total time=   0.0s
# [CV 4/5] END DTC__max_depth=None, DTC__min_samples_leaf=25, DTC__min_samples_split=25;, score=0.984 total time=   0.0s
# [CV 5/5] END DTC__max_depth=None, DTC__min_samples_leaf=25, DTC__min_samples_split=25;, score=0.982 total time=   0.0s
# [CV 1/5] END DTC__max_depth=None, DTC__min_samples_leaf=25, DTC__min_samples_split=50;, score=0.987 total time=   0.0s
# [CV 2/5] END DTC__max_depth=None, DTC__min_samples_leaf=25, DTC__min_samples_split=50;, score=0.988 total time=   0.0s
# [CV 3/5] END DTC__max_depth=None, DTC__min_samples_leaf=25, DTC__min_samples_split=50;, score=0.982 total time=   0.0s
# [CV 4/5] END DTC__max_depth=None, DTC__min_samples_leaf=25, DTC__min_samples_split=50;, score=0.984 total time=   0.0s
# [CV 5/5] END DTC__max_depth=None, DTC__min_samples_leaf=25, DTC__min_samples_split=50;, score=0.982 total time=   0.0s
# [CV 1/5] END DTC__max_depth=None, DTC__min_samples_leaf=50, DTC__min_samples_split=2;, score=0.989 total time=   0.0s
# [CV 2/5] END DTC__max_depth=None, DTC__min_samples_leaf=50, DTC__min_samples_split=2;, score=0.985 total time=   0.0s
# [CV 3/5] END DTC__max_depth=None, DTC__min_samples_leaf=50, DTC__min_samples_split=2;, score=0.983 total time=   0.0s
# [CV 4/5] END DTC__max_depth=None, DTC__min_samples_leaf=50, DTC__min_samples_split=2;, score=0.982 total time=   0.0s
# [CV 5/5] END DTC__max_depth=None, DTC__min_samples_leaf=50, DTC__min_samples_split=2;, score=0.986 total time=   0.0s
# [CV 1/5] END DTC__max_depth=None, DTC__min_samples_leaf=50, DTC__min_samples_split=10;, score=0.989 total time=   0.0s
# [CV 2/5] END DTC__max_depth=None, DTC__min_samples_leaf=50, DTC__min_samples_split=10;, score=0.985 total time=   0.0s
# [CV 3/5] END DTC__max_depth=None, DTC__min_samples_leaf=50, DTC__min_samples_split=10;, score=0.983 total time=   0.0s
# [CV 4/5] END DTC__max_depth=None, DTC__min_samples_leaf=50, DTC__min_samples_split=10;, score=0.982 total time=   0.0s
# [CV 5/5] END DTC__max_depth=None, DTC__min_samples_leaf=50, DTC__min_samples_split=10;, score=0.986 total time=   0.0s
# [CV 1/5] END DTC__max_depth=None, DTC__min_samples_leaf=50, DTC__min_samples_split=25;, score=0.989 total time=   0.0s
# [CV 2/5] END DTC__max_depth=None, DTC__min_samples_leaf=50, DTC__min_samples_split=25;, score=0.985 total time=   0.0s
# [CV 3/5] END DTC__max_depth=None, DTC__min_samples_leaf=50, DTC__min_samples_split=25;, score=0.983 total time=   0.0s
# [CV 4/5] END DTC__max_depth=None, DTC__min_samples_leaf=50, DTC__min_samples_split=25;, score=0.982 total time=   0.0s
# [CV 5/5] END DTC__max_depth=None, DTC__min_samples_leaf=50, DTC__min_samples_split=25;, score=0.986 total time=   0.0s
# [CV 1/5] END DTC__max_depth=None, DTC__min_samples_leaf=50, DTC__min_samples_split=50;, score=0.989 total time=   0.0s
# [CV 2/5] END DTC__max_depth=None, DTC__min_samples_leaf=50, DTC__min_samples_split=50;, score=0.985 total time=   0.0s
# [CV 3/5] END DTC__max_depth=None, DTC__min_samples_leaf=50, DTC__min_samples_split=50;, score=0.983 total time=   0.0s
# [CV 4/5] END DTC__max_depth=None, DTC__min_samples_leaf=50, DTC__min_samples_split=50;, score=0.982 total time=   0.0s
# [CV 5/5] END DTC__max_depth=None, DTC__min_samples_leaf=50, DTC__min_samples_split=50;, score=0.986 total time=   0.0s
# [CV 1/5] END DTC__max_depth=4, DTC__min_samples_leaf=1, DTC__min_samples_split=2;, score=0.976 total time=   0.0s
# [CV 2/5] END DTC__max_depth=4, DTC__min_samples_leaf=1, DTC__min_samples_split=2;, score=0.973 total time=   0.0s
# [CV 3/5] END DTC__max_depth=4, DTC__min_samples_leaf=1, DTC__min_samples_split=2;, score=0.971 total time=   0.0s
# [CV 4/5] END DTC__max_depth=4, DTC__min_samples_leaf=1, DTC__min_samples_split=2;, score=0.963 total time=   0.0s
# [CV 5/5] END DTC__max_depth=4, DTC__min_samples_leaf=1, DTC__min_samples_split=2;, score=0.975 total time=   0.0s
# [CV 1/5] END DTC__max_depth=4, DTC__min_samples_leaf=1, DTC__min_samples_split=10;, score=0.976 total time=   0.0s
# [CV 2/5] END DTC__max_depth=4, DTC__min_samples_leaf=1, DTC__min_samples_split=10;, score=0.973 total time=   0.0s
# [CV 3/5] END DTC__max_depth=4, DTC__min_samples_leaf=1, DTC__min_samples_split=10;, score=0.971 total time=   0.0s
# [CV 4/5] END DTC__max_depth=4, DTC__min_samples_leaf=1, DTC__min_samples_split=10;, score=0.963 total time=   0.0s
# [CV 5/5] END DTC__max_depth=4, DTC__min_samples_leaf=1, DTC__min_samples_split=10;, score=0.975 total time=   0.0s
# [CV 1/5] END DTC__max_depth=4, DTC__min_samples_leaf=1, DTC__min_samples_split=25;, score=0.976 total time=   0.0s
# [CV 2/5] END DTC__max_depth=4, DTC__min_samples_leaf=1, DTC__min_samples_split=25;, score=0.973 total time=   0.0s
# [CV 3/5] END DTC__max_depth=4, DTC__min_samples_leaf=1, DTC__min_samples_split=25;, score=0.971 total time=   0.0s
# [CV 4/5] END DTC__max_depth=4, DTC__min_samples_leaf=1, DTC__min_samples_split=25;, score=0.963 total time=   0.0s
# [CV 5/5] END DTC__max_depth=4, DTC__min_samples_leaf=1, DTC__min_samples_split=25;, score=0.975 total time=   0.0s
# [CV 1/5] END DTC__max_depth=4, DTC__min_samples_leaf=1, DTC__min_samples_split=50;, score=0.976 total time=   0.0s
# [CV 2/5] END DTC__max_depth=4, DTC__min_samples_leaf=1, DTC__min_samples_split=50;, score=0.973 total time=   0.0s
# [CV 3/5] END DTC__max_depth=4, DTC__min_samples_leaf=1, DTC__min_samples_split=50;, score=0.971 total time=   0.0s
# [CV 4/5] END DTC__max_depth=4, DTC__min_samples_leaf=1, DTC__min_samples_split=50;, score=0.963 total time=   0.0s
# [CV 5/5] END DTC__max_depth=4, DTC__min_samples_leaf=1, DTC__min_samples_split=50;, score=0.975 total time=   0.0s
# [CV 1/5] END DTC__max_depth=4, DTC__min_samples_leaf=10, DTC__min_samples_split=2;, score=0.978 total time=   0.0s
# [CV 2/5] END DTC__max_depth=4, DTC__min_samples_leaf=10, DTC__min_samples_split=2;, score=0.973 total time=   0.0s
# [CV 3/5] END DTC__max_depth=4, DTC__min_samples_leaf=10, DTC__min_samples_split=2;, score=0.973 total time=   0.0s
# [CV 4/5] END DTC__max_depth=4, DTC__min_samples_leaf=10, DTC__min_samples_split=2;, score=0.964 total time=   0.0s
# [CV 5/5] END DTC__max_depth=4, DTC__min_samples_leaf=10, DTC__min_samples_split=2;, score=0.977 total time=   0.0s
# [CV 1/5] END DTC__max_depth=4, DTC__min_samples_leaf=10, DTC__min_samples_split=10;, score=0.978 total time=   0.0s
# [CV 2/5] END DTC__max_depth=4, DTC__min_samples_leaf=10, DTC__min_samples_split=10;, score=0.973 total time=   0.0s
# [CV 3/5] END DTC__max_depth=4, DTC__min_samples_leaf=10, DTC__min_samples_split=10;, score=0.973 total time=   0.0s
# [CV 4/5] END DTC__max_depth=4, DTC__min_samples_leaf=10, DTC__min_samples_split=10;, score=0.964 total time=   0.0s
# [CV 5/5] END DTC__max_depth=4, DTC__min_samples_leaf=10, DTC__min_samples_split=10;, score=0.977 total time=   0.0s
# [CV 1/5] END DTC__max_depth=4, DTC__min_samples_leaf=10, DTC__min_samples_split=25;, score=0.978 total time=   0.0s
# [CV 2/5] END DTC__max_depth=4, DTC__min_samples_leaf=10, DTC__min_samples_split=25;, score=0.973 total time=   0.0s
# [CV 3/5] END DTC__max_depth=4, DTC__min_samples_leaf=10, DTC__min_samples_split=25;, score=0.973 total time=   0.0s
# [CV 4/5] END DTC__max_depth=4, DTC__min_samples_leaf=10, DTC__min_samples_split=25;, score=0.964 total time=   0.0s
# [CV 5/5] END DTC__max_depth=4, DTC__min_samples_leaf=10, DTC__min_samples_split=25;, score=0.977 total time=   0.0s
# [CV 1/5] END DTC__max_depth=4, DTC__min_samples_leaf=10, DTC__min_samples_split=50;, score=0.978 total time=   0.0s
# [CV 2/5] END DTC__max_depth=4, DTC__min_samples_leaf=10, DTC__min_samples_split=50;, score=0.973 total time=   0.0s
# [CV 3/5] END DTC__max_depth=4, DTC__min_samples_leaf=10, DTC__min_samples_split=50;, score=0.973 total time=   0.0s
# [CV 4/5] END DTC__max_depth=4, DTC__min_samples_leaf=10, DTC__min_samples_split=50;, score=0.964 total time=   0.0s
# [CV 5/5] END DTC__max_depth=4, DTC__min_samples_leaf=10, DTC__min_samples_split=50;, score=0.977 total time=   0.0s
# [CV 1/5] END DTC__max_depth=4, DTC__min_samples_leaf=25, DTC__min_samples_split=2;, score=0.978 total time=   0.0s
# [CV 2/5] END DTC__max_depth=4, DTC__min_samples_leaf=25, DTC__min_samples_split=2;, score=0.973 total time=   0.0s
# [CV 3/5] END DTC__max_depth=4, DTC__min_samples_leaf=25, DTC__min_samples_split=2;, score=0.973 total time=   0.0s
# [CV 4/5] END DTC__max_depth=4, DTC__min_samples_leaf=25, DTC__min_samples_split=2;, score=0.964 total time=   0.0s
# [CV 5/5] END DTC__max_depth=4, DTC__min_samples_leaf=25, DTC__min_samples_split=2;, score=0.977 total time=   0.0s
# [CV 1/5] END DTC__max_depth=4, DTC__min_samples_leaf=25, DTC__min_samples_split=10;, score=0.978 total time=   0.0s
# [CV 2/5] END DTC__max_depth=4, DTC__min_samples_leaf=25, DTC__min_samples_split=10;, score=0.973 total time=   0.0s
# [CV 3/5] END DTC__max_depth=4, DTC__min_samples_leaf=25, DTC__min_samples_split=10;, score=0.973 total time=   0.0s
# [CV 4/5] END DTC__max_depth=4, DTC__min_samples_leaf=25, DTC__min_samples_split=10;, score=0.964 total time=   0.0s
# [CV 5/5] END DTC__max_depth=4, DTC__min_samples_leaf=25, DTC__min_samples_split=10;, score=0.977 total time=   0.0s
# [CV 1/5] END DTC__max_depth=4, DTC__min_samples_leaf=25, DTC__min_samples_split=25;, score=0.978 total time=   0.0s
# [CV 2/5] END DTC__max_depth=4, DTC__min_samples_leaf=25, DTC__min_samples_split=25;, score=0.973 total time=   0.0s
# [CV 3/5] END DTC__max_depth=4, DTC__min_samples_leaf=25, DTC__min_samples_split=25;, score=0.973 total time=   0.0s
# [CV 4/5] END DTC__max_depth=4, DTC__min_samples_leaf=25, DTC__min_samples_split=25;, score=0.964 total time=   0.0s
# [CV 5/5] END DTC__max_depth=4, DTC__min_samples_leaf=25, DTC__min_samples_split=25;, score=0.977 total time=   0.0s
# [CV 1/5] END DTC__max_depth=4, DTC__min_samples_leaf=25, DTC__min_samples_split=50;, score=0.978 total time=   0.0s
# [CV 2/5] END DTC__max_depth=4, DTC__min_samples_leaf=25, DTC__min_samples_split=50;, score=0.973 total time=   0.0s
# [CV 3/5] END DTC__max_depth=4, DTC__min_samples_leaf=25, DTC__min_samples_split=50;, score=0.973 total time=   0.0s
# [CV 4/5] END DTC__max_depth=4, DTC__min_samples_leaf=25, DTC__min_samples_split=50;, score=0.964 total time=   0.0s
# [CV 5/5] END DTC__max_depth=4, DTC__min_samples_leaf=25, DTC__min_samples_split=50;, score=0.977 total time=   0.0s
# [CV 1/5] END DTC__max_depth=4, DTC__min_samples_leaf=50, DTC__min_samples_split=2;, score=0.978 total time=   0.0s
# [CV 2/5] END DTC__max_depth=4, DTC__min_samples_leaf=50, DTC__min_samples_split=2;, score=0.973 total time=   0.0s
# [CV 3/5] END DTC__max_depth=4, DTC__min_samples_leaf=50, DTC__min_samples_split=2;, score=0.973 total time=   0.0s
# [CV 4/5] END DTC__max_depth=4, DTC__min_samples_leaf=50, DTC__min_samples_split=2;, score=0.965 total time=   0.0s
# [CV 5/5] END DTC__max_depth=4, DTC__min_samples_leaf=50, DTC__min_samples_split=2;, score=0.978 total time=   0.0s
# [CV 1/5] END DTC__max_depth=4, DTC__min_samples_leaf=50, DTC__min_samples_split=10;, score=0.978 total time=   0.0s
# [CV 2/5] END DTC__max_depth=4, DTC__min_samples_leaf=50, DTC__min_samples_split=10;, score=0.973 total time=   0.0s
# [CV 3/5] END DTC__max_depth=4, DTC__min_samples_leaf=50, DTC__min_samples_split=10;, score=0.973 total time=   0.0s
# [CV 4/5] END DTC__max_depth=4, DTC__min_samples_leaf=50, DTC__min_samples_split=10;, score=0.965 total time=   0.0s
# [CV 5/5] END DTC__max_depth=4, DTC__min_samples_leaf=50, DTC__min_samples_split=10;, score=0.978 total time=   0.0s
# [CV 1/5] END DTC__max_depth=4, DTC__min_samples_leaf=50, DTC__min_samples_split=25;, score=0.978 total time=   0.0s
# [CV 2/5] END DTC__max_depth=4, DTC__min_samples_leaf=50, DTC__min_samples_split=25;, score=0.973 total time=   0.0s
# [CV 3/5] END DTC__max_depth=4, DTC__min_samples_leaf=50, DTC__min_samples_split=25;, score=0.973 total time=   0.0s
# [CV 4/5] END DTC__max_depth=4, DTC__min_samples_leaf=50, DTC__min_samples_split=25;, score=0.965 total time=   0.0s
# [CV 5/5] END DTC__max_depth=4, DTC__min_samples_leaf=50, DTC__min_samples_split=25;, score=0.978 total time=   0.0s
# [CV 1/5] END DTC__max_depth=4, DTC__min_samples_leaf=50, DTC__min_samples_split=50;, score=0.978 total time=   0.0s
# [CV 2/5] END DTC__max_depth=4, DTC__min_samples_leaf=50, DTC__min_samples_split=50;, score=0.973 total time=   0.0s
# [CV 3/5] END DTC__max_depth=4, DTC__min_samples_leaf=50, DTC__min_samples_split=50;, score=0.973 total time=   0.0s
# [CV 4/5] END DTC__max_depth=4, DTC__min_samples_leaf=50, DTC__min_samples_split=50;, score=0.965 total time=   0.0s
# [CV 5/5] END DTC__max_depth=4, DTC__min_samples_leaf=50, DTC__min_samples_split=50;, score=0.978 total time=   0.0s
# [CV 1/5] END DTC__max_depth=6, DTC__min_samples_leaf=1, DTC__min_samples_split=2;, score=0.984 total time=   0.0s
# [CV 2/5] END DTC__max_depth=6, DTC__min_samples_leaf=1, DTC__min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 3/5] END DTC__max_depth=6, DTC__min_samples_leaf=1, DTC__min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 4/5] END DTC__max_depth=6, DTC__min_samples_leaf=1, DTC__min_samples_split=2;, score=0.971 total time=   0.0s
# [CV 5/5] END DTC__max_depth=6, DTC__min_samples_leaf=1, DTC__min_samples_split=2;, score=0.979 total time=   0.0s
# [CV 1/5] END DTC__max_depth=6, DTC__min_samples_leaf=1, DTC__min_samples_split=10;, score=0.984 total time=   0.0s
# [CV 2/5] END DTC__max_depth=6, DTC__min_samples_leaf=1, DTC__min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 3/5] END DTC__max_depth=6, DTC__min_samples_leaf=1, DTC__min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 4/5] END DTC__max_depth=6, DTC__min_samples_leaf=1, DTC__min_samples_split=10;, score=0.971 total time=   0.0s
# [CV 5/5] END DTC__max_depth=6, DTC__min_samples_leaf=1, DTC__min_samples_split=10;, score=0.980 total time=   0.0s
# [CV 1/5] END DTC__max_depth=6, DTC__min_samples_leaf=1, DTC__min_samples_split=25;, score=0.984 total time=   0.0s
# [CV 2/5] END DTC__max_depth=6, DTC__min_samples_leaf=1, DTC__min_samples_split=25;, score=0.981 total time=   0.0s
# [CV 3/5] END DTC__max_depth=6, DTC__min_samples_leaf=1, DTC__min_samples_split=25;, score=0.981 total time=   0.0s
# [CV 4/5] END DTC__max_depth=6, DTC__min_samples_leaf=1, DTC__min_samples_split=25;, score=0.971 total time=   0.0s
# [CV 5/5] END DTC__max_depth=6, DTC__min_samples_leaf=1, DTC__min_samples_split=25;, score=0.980 total time=   0.0s
# [CV 1/5] END DTC__max_depth=6, DTC__min_samples_leaf=1, DTC__min_samples_split=50;, score=0.984 total time=   0.0s
# [CV 2/5] END DTC__max_depth=6, DTC__min_samples_leaf=1, DTC__min_samples_split=50;, score=0.981 total time=   0.0s
# [CV 3/5] END DTC__max_depth=6, DTC__min_samples_leaf=1, DTC__min_samples_split=50;, score=0.981 total time=   0.0s
# [CV 4/5] END DTC__max_depth=6, DTC__min_samples_leaf=1, DTC__min_samples_split=50;, score=0.970 total time=   0.0s
# [CV 5/5] END DTC__max_depth=6, DTC__min_samples_leaf=1, DTC__min_samples_split=50;, score=0.979 total time=   0.0s
# [CV 1/5] END DTC__max_depth=6, DTC__min_samples_leaf=10, DTC__min_samples_split=2;, score=0.988 total time=   0.0s
# [CV 2/5] END DTC__max_depth=6, DTC__min_samples_leaf=10, DTC__min_samples_split=2;, score=0.982 total time=   0.0s
# [CV 3/5] END DTC__max_depth=6, DTC__min_samples_leaf=10, DTC__min_samples_split=2;, score=0.982 total time=   0.0s
# [CV 4/5] END DTC__max_depth=6, DTC__min_samples_leaf=10, DTC__min_samples_split=2;, score=0.970 total time=   0.0s
# [CV 5/5] END DTC__max_depth=6, DTC__min_samples_leaf=10, DTC__min_samples_split=2;, score=0.980 total time=   0.0s
# [CV 1/5] END DTC__max_depth=6, DTC__min_samples_leaf=10, DTC__min_samples_split=10;, score=0.988 total time=   0.0s
# [CV 2/5] END DTC__max_depth=6, DTC__min_samples_leaf=10, DTC__min_samples_split=10;, score=0.982 total time=   0.0s
# [CV 3/5] END DTC__max_depth=6, DTC__min_samples_leaf=10, DTC__min_samples_split=10;, score=0.982 total time=   0.0s
# [CV 4/5] END DTC__max_depth=6, DTC__min_samples_leaf=10, DTC__min_samples_split=10;, score=0.970 total time=   0.0s
# [CV 5/5] END DTC__max_depth=6, DTC__min_samples_leaf=10, DTC__min_samples_split=10;, score=0.980 total time=   0.0s
# [CV 1/5] END DTC__max_depth=6, DTC__min_samples_leaf=10, DTC__min_samples_split=25;, score=0.988 total time=   0.0s
# [CV 2/5] END DTC__max_depth=6, DTC__min_samples_leaf=10, DTC__min_samples_split=25;, score=0.982 total time=   0.0s
# [CV 3/5] END DTC__max_depth=6, DTC__min_samples_leaf=10, DTC__min_samples_split=25;, score=0.982 total time=   0.0s
# [CV 4/5] END DTC__max_depth=6, DTC__min_samples_leaf=10, DTC__min_samples_split=25;, score=0.970 total time=   0.0s
# [CV 5/5] END DTC__max_depth=6, DTC__min_samples_leaf=10, DTC__min_samples_split=25;, score=0.980 total time=   0.0s
# [CV 1/5] END DTC__max_depth=6, DTC__min_samples_leaf=10, DTC__min_samples_split=50;, score=0.988 total time=   0.0s
# [CV 2/5] END DTC__max_depth=6, DTC__min_samples_leaf=10, DTC__min_samples_split=50;, score=0.982 total time=   0.0s
# [CV 3/5] END DTC__max_depth=6, DTC__min_samples_leaf=10, DTC__min_samples_split=50;, score=0.982 total time=   0.0s
# [CV 4/5] END DTC__max_depth=6, DTC__min_samples_leaf=10, DTC__min_samples_split=50;, score=0.969 total time=   0.0s
# [CV 5/5] END DTC__max_depth=6, DTC__min_samples_leaf=10, DTC__min_samples_split=50;, score=0.980 total time=   0.0s
# [CV 1/5] END DTC__max_depth=6, DTC__min_samples_leaf=25, DTC__min_samples_split=2;, score=0.988 total time=   0.0s
# [CV 2/5] END DTC__max_depth=6, DTC__min_samples_leaf=25, DTC__min_samples_split=2;, score=0.982 total time=   0.0s
# [CV 3/5] END DTC__max_depth=6, DTC__min_samples_leaf=25, DTC__min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 4/5] END DTC__max_depth=6, DTC__min_samples_leaf=25, DTC__min_samples_split=2;, score=0.973 total time=   0.0s
# [CV 5/5] END DTC__max_depth=6, DTC__min_samples_leaf=25, DTC__min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 1/5] END DTC__max_depth=6, DTC__min_samples_leaf=25, DTC__min_samples_split=10;, score=0.988 total time=   0.0s
# [CV 2/5] END DTC__max_depth=6, DTC__min_samples_leaf=25, DTC__min_samples_split=10;, score=0.982 total time=   0.0s
# [CV 3/5] END DTC__max_depth=6, DTC__min_samples_leaf=25, DTC__min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 4/5] END DTC__max_depth=6, DTC__min_samples_leaf=25, DTC__min_samples_split=10;, score=0.973 total time=   0.0s
# [CV 5/5] END DTC__max_depth=6, DTC__min_samples_leaf=25, DTC__min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 1/5] END DTC__max_depth=6, DTC__min_samples_leaf=25, DTC__min_samples_split=25;, score=0.988 total time=   0.0s
# [CV 2/5] END DTC__max_depth=6, DTC__min_samples_leaf=25, DTC__min_samples_split=25;, score=0.982 total time=   0.0s
# [CV 3/5] END DTC__max_depth=6, DTC__min_samples_leaf=25, DTC__min_samples_split=25;, score=0.981 total time=   0.0s
# [CV 4/5] END DTC__max_depth=6, DTC__min_samples_leaf=25, DTC__min_samples_split=25;, score=0.973 total time=   0.0s
# [CV 5/5] END DTC__max_depth=6, DTC__min_samples_leaf=25, DTC__min_samples_split=25;, score=0.981 total time=   0.0s
# [CV 1/5] END DTC__max_depth=6, DTC__min_samples_leaf=25, DTC__min_samples_split=50;, score=0.988 total time=   0.0s
# [CV 2/5] END DTC__max_depth=6, DTC__min_samples_leaf=25, DTC__min_samples_split=50;, score=0.982 total time=   0.0s
# [CV 3/5] END DTC__max_depth=6, DTC__min_samples_leaf=25, DTC__min_samples_split=50;, score=0.981 total time=   0.0s
# [CV 4/5] END DTC__max_depth=6, DTC__min_samples_leaf=25, DTC__min_samples_split=50;, score=0.973 total time=   0.0s
# [CV 5/5] END DTC__max_depth=6, DTC__min_samples_leaf=25, DTC__min_samples_split=50;, score=0.981 total time=   0.0s
# [CV 1/5] END DTC__max_depth=6, DTC__min_samples_leaf=50, DTC__min_samples_split=2;, score=0.987 total time=   0.0s
# [CV 2/5] END DTC__max_depth=6, DTC__min_samples_leaf=50, DTC__min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 3/5] END DTC__max_depth=6, DTC__min_samples_leaf=50, DTC__min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 4/5] END DTC__max_depth=6, DTC__min_samples_leaf=50, DTC__min_samples_split=2;, score=0.974 total time=   0.0s
# [CV 5/5] END DTC__max_depth=6, DTC__min_samples_leaf=50, DTC__min_samples_split=2;, score=0.983 total time=   0.0s
# [CV 1/5] END DTC__max_depth=6, DTC__min_samples_leaf=50, DTC__min_samples_split=10;, score=0.987 total time=   0.0s
# [CV 2/5] END DTC__max_depth=6, DTC__min_samples_leaf=50, DTC__min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 3/5] END DTC__max_depth=6, DTC__min_samples_leaf=50, DTC__min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 4/5] END DTC__max_depth=6, DTC__min_samples_leaf=50, DTC__min_samples_split=10;, score=0.974 total time=   0.0s
# [CV 5/5] END DTC__max_depth=6, DTC__min_samples_leaf=50, DTC__min_samples_split=10;, score=0.983 total time=   0.0s
# [CV 1/5] END DTC__max_depth=6, DTC__min_samples_leaf=50, DTC__min_samples_split=25;, score=0.987 total time=   0.0s
# [CV 2/5] END DTC__max_depth=6, DTC__min_samples_leaf=50, DTC__min_samples_split=25;, score=0.981 total time=   0.0s
# [CV 3/5] END DTC__max_depth=6, DTC__min_samples_leaf=50, DTC__min_samples_split=25;, score=0.981 total time=   0.0s
# [CV 4/5] END DTC__max_depth=6, DTC__min_samples_leaf=50, DTC__min_samples_split=25;, score=0.974 total time=   0.0s
# [CV 5/5] END DTC__max_depth=6, DTC__min_samples_leaf=50, DTC__min_samples_split=25;, score=0.983 total time=   0.0s
# [CV 1/5] END DTC__max_depth=6, DTC__min_samples_leaf=50, DTC__min_samples_split=50;, score=0.987 total time=   0.0s
# [CV 2/5] END DTC__max_depth=6, DTC__min_samples_leaf=50, DTC__min_samples_split=50;, score=0.981 total time=   0.0s
# [CV 3/5] END DTC__max_depth=6, DTC__min_samples_leaf=50, DTC__min_samples_split=50;, score=0.981 total time=   0.0s
# [CV 4/5] END DTC__max_depth=6, DTC__min_samples_leaf=50, DTC__min_samples_split=50;, score=0.974 total time=   0.0s
# [CV 5/5] END DTC__max_depth=6, DTC__min_samples_leaf=50, DTC__min_samples_split=50;, score=0.983 total time=   0.0s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=24, shuffle=True),
#              estimator=Pipeline(steps=[('OHE',
#                                         ColumnTransformer(transformers=[('passthrough',
#                                                                          'passthrough',
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x000001374FB88110>),
#                                                                         ('onehotencoder',
#                                                                          OneHotEncoder(drop='first',
#                                                                                        handle_unknown='ignore',
#                                                                                        sparse_output=False),
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x000001374FC95970>)],
#                                                           verbose_feature_names_out=False)),
#                                        ('SCL', StandardScaler()),
#                                        ('DTC',
#                                         DecisionTreeClassifier(random_state=24))]),
#              param_grid={'DTC__max_depth': [None, 4, 6],
#                          'DTC__min_samples_leaf': [1, 10, 25, 50],
#                          'DTC__min_samples_split': [2, 10, 25, 50]},
#              scoring='roc_auc', verbose=3)

# %%
# Out:
# sklearn.pipeline.Pipeline

# %%
print(gcv.best_score_)
print(gcv.best_params_)
# Out:
# 0.9861975700061546
# {'DTC__max_depth': None, 'DTC__min_samples_leaf': 10, 'DTC__min_samples_split': 25}

# %%
best_tree = gcv.best_estimator_.named_steps['DTC']

plt.figure(figsize = (50, 35))
plot_tree(best_tree, 
          # feature_names = list(X.columns), 
          class_names = ["0", "1"],
          filled = True, 
          fontsize = 20,
         )

plt.show()

# %%
print(gcv.best_estimator_[2])

# %%
best_tree.feature_importances_
# Out:
# array([5.21808499e-01, 1.46190125e-01, 1.06596857e-01, 7.27943172e-02,
#        1.48799111e-01, 3.09761644e-04, 3.66928161e-05, 0.00000000e+00,
#        1.10537168e-04, 1.75279213e-04, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.07647189e-03, 1.22805395e-04, 9.04012321e-04,
#        5.41919537e-04, 5.33609873e-04])

# %%
df_imp  = pd.DataFrame({"feature" : gcv.best_estimator_.named_steps['OHE'].get_feature_names_out(), 
                        "importance" : best_tree.feature_importances_})       # Note here OHE refers to Column transformer not encoder
df_imp.sort_values("importance", inplace = True, )
plt.barh(df_imp["feature"], df_imp["importance"])
plt.show()


# print(df_imp)
