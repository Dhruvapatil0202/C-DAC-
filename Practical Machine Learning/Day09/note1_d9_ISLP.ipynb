# %%
import pandas as pd
import numpy as np
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression, LogisticRegression, ElasticNet, LinearRegression
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV, KFold
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, confusion_matrix, log_loss, roc_auc_score, r2_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.decomposition import PCA
from sklearn.svm import SVC

from sklearn.tree import DecisionTreeClassifier, plot_tree

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, VotingRegressor

import warnings
warnings.filterwarnings('ignore')

# %%
from ISLP import load_data
credit = load_data('Credit')
credit.drop("ID", axis = 1, inplace = True)

# %%
credit.head()
# Out:
#     Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 0   14.891   3606     283      2   34         11    Male      No     Yes
# 1  106.025   6645     483      3   82         15  Female     Yes     Yes
# 2  104.593   7075     514      4   71         11    Male      No      No
# 3  148.924   9504     681      3   36         11  Female      No      No
# 4   55.882   4897     357      2   68         16    Male      No     Yes
#
#    Ethnicity  Balance
# 0  Caucasian      333
# 1      Asian      903
# 2      Asian      580
# 3      Asian      964
# 4  Caucasian      331

# %%
x = credit.drop("Balance", axis=1)
y = credit["Balance"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, 
                                                    test_size = 0.3, 
                                                   random_state = 24)

# %%
# ______________________________________________________________________________________
# Pipeline

# one hot encoder
ohe = OneHotEncoder(
    handle_unknown="ignore",
    sparse_output=False,
    drop='first'
).set_output(transform='pandas')

trans_ohe = make_column_transformer(
    ('passthrough', make_column_selector(dtype_exclude='category')),
    (ohe, make_column_selector(dtype_include='category')),
    verbose_feature_names_out=False
).set_output(transform='pandas')


# scaler
scl_std = StandardScaler().set_output(transform = "pandas")
scl_mm = MinMaxScaler().set_output(transform = "pandas")


# Model

dtc = DecisionTreeRegressor()
knn = KNeighborsRegressor()
eln = ElasticNet()

vor = VotingRegressor([("DTC", dtc), ("KNN", knn), ("ELN", eln)])


pipe = Pipeline([("OHE", trans_ohe), ("SCL", scl_mm), ("VOR", vor)])


# _____________________________________________________________________________________
# GCV

params = {
    'VOR__DTC__max_depth' : [None, 3, 5],
    'VOR__DTC__min_samples_leaf' : [1, 5, 10],
    'VOR__DTC__min_samples_split' : [2, 5, 10],
     # 'VOR__KNN__algorithm' : ['auto', 'brute'],
     # 'VOR__KNN__metric' : ['cosine', 'l2', 'l1', 'manhattan', 'euclidean'],
     'VOR__KNN__n_neighbors' : [2, 5, 7], 
     'VOR__ELN__alpha' : np.linspace(0.001, 3, 3),
     'VOR__ELN__l1_ratio' : np.linspace(0.001, 1, 3),
    'VOR__weights' : [[6, 3, 6], [7, 4, 7], [9, 2, 9]]
}

kfolds = StratifiedKFold(n_splits = 5,
                        random_state = 24,
                        shuffle = True)

kfold = KFold(n_splits = 5,
            random_state = 24,
            shuffle = True)

gcv = GridSearchCV(pipe,
                  param_grid = params,
                  scoring = "r2",
                  cv = kfold,
                  verbose = 3)


# gcv.fit(x, y)

# %%
gcv.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 2187 candidates, totalling 10935 fits
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.874 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.930 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.953 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.937 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.920 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.868 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.931 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.941 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.941 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.914 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.910 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.937 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.958 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.957 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.947 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.872 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.907 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.942 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.937 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.941 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.862 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.895 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.936 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.929 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.929 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.899 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.932 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.950 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.961 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.952 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.883 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.900 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.949 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.934 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.939 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.854 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.894 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.948 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.926 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.935 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.908 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.932 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.963 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.954 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.953 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.887 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.930 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.950 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.941 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.923 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.866 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.925 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.941 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.941 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.918 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.922 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.943 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.955 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.955 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.944 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.877 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.914 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.951 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.940 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.934 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.880 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.899 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.941 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.933 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.932 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.908 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.938 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.965 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.953 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.953 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.880 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.911 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.955 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.941 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.942 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.869 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.898 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.951 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.939 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.938 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.911 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.930 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.957 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.960 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.958 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.892 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.935 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.950 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.941 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.931 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.881 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.933 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.945 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.941 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.921 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.929 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.956 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.963 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.960 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.949 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.891 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.910 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.950 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.940 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.941 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.883 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.910 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.940 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.941 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.932 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.917 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.944 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.961 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.960 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.951 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.891 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.909 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.953 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.940 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.941 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.879 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.907 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.956 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.937 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.933 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.917 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.943 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.964 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.958 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=0.001, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.954 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.601 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.671 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.811 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.728 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.699 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.603 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.659 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.803 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.710 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.683 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.644 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.655 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.804 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.706 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.708 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.587 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.624 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.771 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.693 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.676 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.576 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.625 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.756 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.686 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.693 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.625 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.644 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.782 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.707 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.699 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.595 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.615 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.761 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.688 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.684 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.543 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.625 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.750 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.676 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.678 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.641 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.625 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.770 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.689 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.001, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.690 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.634 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.684 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.810 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.738 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.723 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.613 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.685 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.803 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.731 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.704 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.632 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.678 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.813 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.728 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.722 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.588 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.636 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.778 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.700 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.696 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.576 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.642 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.775 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.692 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.706 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.641 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.685 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=None, VOR__DTC__min_samples_leaf=1, VOR__DTC__min_samples_split=2, VOR__ELN__alpha=1.5005, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.799 total time=   0.0s
# ...
# [CV 3/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.726 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.651 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.682 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.477 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.628 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.708 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.632 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.669 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.470 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.624 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.706 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.628 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.667 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.505 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.647 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.720 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.645 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=0.5005, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.678 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.787 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.925 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.924 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.916 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[6, 3, 6];, score=0.901 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.780 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.922 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.921 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.912 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[7, 4, 7];, score=0.895 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.813 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.933 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.930 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.931 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=2, VOR__weights=[9, 2, 9];, score=0.921 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.776 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.908 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.916 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.907 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[6, 3, 6];, score=0.912 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.767 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.902 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.912 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.901 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[7, 4, 7];, score=0.908 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.807 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.929 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.925 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.926 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=5, VOR__weights=[9, 2, 9];, score=0.925 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.773 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.896 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.913 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.903 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[6, 3, 6];, score=0.914 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.764 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.895 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.910 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.897 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[7, 4, 7];, score=0.910 total time=   0.0s
# [CV 1/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.805 total time=   0.0s
# [CV 2/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.927 total time=   0.0s
# [CV 3/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.924 total time=   0.0s
# [CV 4/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.924 total time=   0.0s
# [CV 5/5] END VOR__DTC__max_depth=5, VOR__DTC__min_samples_leaf=10, VOR__DTC__min_samples_split=10, VOR__ELN__alpha=3.0, VOR__ELN__l1_ratio=1.0, VOR__KNN__n_neighbors=7, VOR__weights=[9, 2, 9];, score=0.926 total time=   0.0s
# GridSearchCV(cv=KFold(n_splits=5, random_state=24, shuffle=True),
#              estimator=Pipeline(steps=[('OHE',
#                                         ColumnTransformer(transformers=[('passthrough',
#                                                                          'passthrough',
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x000001D4394FA840>),
#                                                                         ('onehotencoder',
#                                                                          OneHotEncoder(drop='first',
#                                                                                        handle_unknown='ignore',
#                                                                                        sparse_output=False),
#                                                                          <sklearn.compose._...
#                                                                     ('ELN',
#                                                                      ElasticNet())]))]),
#              param_grid={'VOR__DTC__max_depth': [None, 3, 5],
#                          'VOR__DTC__min_samples_leaf': [1, 5, 10],
#                          'VOR__DTC__min_samples_split': [2, 5, 10],
#                          'VOR__ELN__alpha': array([1.0000e-03, 1.5005e+00, 3.0000e+00]),
#                          'VOR__ELN__l1_ratio': array([0.001 , 0.5005, 1.    ]),
#                          'VOR__KNN__n_neighbors': [2, 5, 7],
#                          'VOR__weights': [[6, 3, 6], [7, 4, 7], [9, 2, 9]]},
#              scoring='r2', verbose=3)

# %%
print(gcv.best_score_)
print(gcv.best_params_)
# Out:
# 0.9514012411309487
# {'VOR__DTC__max_depth': None, 'VOR__DTC__min_samples_leaf': 1, 'VOR__DTC__min_samples_split': 2, 'VOR__ELN__alpha': 0.001, 'VOR__ELN__l1_ratio': 1.0, 'VOR__KNN__n_neighbors': 2, 'VOR__weights': [9, 2, 9]}

# %%
y_pred = gcv.predict(x_test)
r2_score(y_test, y_pred)
# Out:
# 0.9388293693955004

# %%
ohe = OneHotEncoder(
    handle_unknown="ignore",
    sparse_output=False,
    drop='first'
).set_output(transform='pandas')

trans_ohe = make_column_transformer(
    ('passthrough', make_column_selector(dtype_exclude='category')),
    (ohe, make_column_selector(dtype_include='category')),
    verbose_feature_names_out=False
).set_output(transform='pandas')

dtc = DecisionTreeRegressor()
knn = KNeighborsRegressor()
eln = ElasticNet()

pipe_dtc = Pipeline([("OHE", trans_ohe), ("DTC", dtc)])
pipe_knn = Pipeline([("OHE", trans_ohe), ("KNN", knn)])
pipe_eln = Pipeline([("OHE", trans_ohe), ("ELN", eln)])

voting = VotingRegressor([("PIPE_DTC", pipe_dtc), ("PIPE_KNN", pipe_knn), ("PIPE_ELN", pipe_eln)])

# %%
voting.fit(x_train, y_train)
# Out:
# VotingRegressor(estimators=[('PIPE_DTC',
#                              Pipeline(steps=[('OHE',
#                                               ColumnTransformer(transformers=[('passthrough',
#                                                                                'passthrough',
#                                                                                <sklearn.compose._column_transformer.make_column_selector object at 0x000001D442A71A30>),
#                                                                               ('onehotencoder',
#                                                                                OneHotEncoder(drop='first',
#                                                                                              handle_unknown='ignore',
#                                                                                              sparse_output=False),
#                                                                                <sklearn.compose._column_transformer.make_column_se...
#                                               ColumnTransformer(transformers=[('passthrough',
#                                                                                'passthrough',
#                                                                                <sklearn.compose._column_transformer.make_column_selector object at 0x000001D442A71A30>),
#                                                                               ('onehotencoder',
#                                                                                OneHotEncoder(drop='first',
#                                                                                              handle_unknown='ignore',
#                                                                                              sparse_output=False),
#                                                                                <sklearn.compose._column_transformer.make_column_selector object at 0x000001D442CAAC90>)],
#                                                                 verbose_feature_names_out=False)),
#                                              ('ELN', ElasticNet())]))])

# %%
y_pred = voting.predict(x_test)
r2_score(y_test, y_pred)
# Out:
# 0.9115187340406501

# %%
pipe_dtc.fit(x_train, y_train)
y_pred_dtc = pipe_dtc.predict(x_test)
r2_score(y_test, y_pred_dtc)
# Out:
# 0.8988895126911057

# %%
pipe_knn.fit(x_train, y_train)
y_pred_knn = pipe_knn.predict(x_test)
r2_score(y_test, y_pred_knn)
# Out:
# 0.7899310404076199

# %%
pipe_eln.fit(x_train, y_train)
y_pred_eln = pipe_eln.predict(x_test)
r2_score(y_test, y_pred_eln)
# Out:
# 0.8940622886507

# %%
voting = VotingRegressor([("PIPE_DTC", pipe_dtc), ("PIPE_KNN", pipe_knn), ("PIPE_ELN", pipe_eln)],
                        weights = [6, 2, 6])
voting.fit(x_train, y_train)
y_pred = voting.predict(x_test)
r2_score(y_test, y_pred)
# Out:
# 0.9286833784569565
