# %%
import pandas as pd
import numpy as np
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression, LogisticRegression, ElasticNet, LinearRegression
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV, KFold
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, confusion_matrix, log_loss, roc_auc_score, r2_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.decomposition import PCA
from sklearn.svm import SVC

from sklearn.tree import DecisionTreeClassifier, plot_tree

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, VotingRegressor, BaggingClassifier

import warnings
warnings.filterwarnings('ignore')

# %%
glass.head(3)
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  \
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
#
#                                Type
# 0  building_windows_float_processed
# 1  building_windows_float_processed
# 2  building_windows_float_processed

# %%
glass = pd.read_csv("Glass.csv")
x = glass.drop('Type', axis = 1)
y = glass['Type']
x_train, x_test, y_train, y_test = train_test_split(x, y, 
                                                    random_state = 24, 
                                                    test_size = 0.3,
                                                   stratify = y,
                                                   )

# %%
lr = LogisticRegression(random_state = 24)
bagg = BaggingClassifier(estimator = lr, random_state = 24)
bagg.fit(x_train, y_train)
y_pred = bagg.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6461538461538462

# %%
svm = SVC(probability = True, random_state=24)
bagg = BaggingClassifier(estimator = svm, random_state = 24)
bagg.fit(x_train, y_train)
y_pred = bagg.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6153846153846154

# %%
lr = LogisticRegression(random_state = 24)
lr.fit(x_train, y_train)
y_pred = lr.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6461538461538462

# %%
svm = SVC(probability = True, random_state=24)
svm.fit(x_train, y_train)
y_pred = svm.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.35384615384615387

# %%
dtc = DecisionTreeClassifier(random_state = 24)
bagg = BaggingClassifier(estimator = dtc, random_state = 24)
bagg.fit(x_train, y_train)
y_pred = bagg.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6615384615384615

# %%
dtc = DecisionTreeClassifier(random_state = 24)
dtc.fit(x_train, y_train)
y_pred = dtc.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.676923076923077

# %%
# ______________________________________________________________________________________
# Pipeline

# one hot encoder
ohe = OneHotEncoder(
    handle_unknown="ignore",
    sparse_output=False,
    drop='first'
).set_output(transform='pandas')

trans_ohe = make_column_transformer(
    ('passthrough', make_column_selector(dtype_exclude=['category', object])),
    (ohe, make_column_selector(dtype_include=['category', object])),
    verbose_feature_names_out=False
).set_output(transform='pandas')


# scaler
scl_std = StandardScaler().set_output(transform = "pandas")
scl_mm = MinMaxScaler().set_output(transform = "pandas")


# Model

dtc = DecisionTreeClassifier()
lr = LogisticRegression()
svm = SVC()

# vor = VotingRegressor([("DTC", dtc), ("LR", lr), ("SVM", svm)])

bagg = BaggingClassifier(random_state = 24)

pipe = Pipeline([("OHE", trans_ohe), ("SCL", scl_mm), ("BAG", bagg)])


# _____________________________________________________________________________________
# GCV

params = {
    "BAG__estimator" : [svm, lr, dtc],
    "BAG__n_estimators" : [10, 50, 100]
}

kfolds = StratifiedKFold(n_splits = 5,
                        random_state = 24,
                        shuffle = True)

kfold = KFold(n_splits = 5,
            random_state = 24,
            shuffle = True)

gcv = GridSearchCV(pipe,
                  param_grid = params,
                  scoring = "neg_log_loss",
                  cv = kfolds,
                  verbose = 3)


# gcv.fit(x, y)

# %%
gcv.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END BAG__estimator=SVC(), BAG__n_estimators=10;, score=-6.401 total time=   0.0s
# [CV 2/5] END BAG__estimator=SVC(), BAG__n_estimators=10;, score=-3.911 total time=   0.0s
# [CV 3/5] END BAG__estimator=SVC(), BAG__n_estimators=10;, score=-6.494 total time=   0.0s
# [CV 4/5] END BAG__estimator=SVC(), BAG__n_estimators=10;, score=-7.625 total time=   0.0s
# [CV 5/5] END BAG__estimator=SVC(), BAG__n_estimators=10;, score=-7.830 total time=   0.0s
# [CV 1/5] END BAG__estimator=SVC(), BAG__n_estimators=50;, score=-4.270 total time=   0.1s
# [CV 2/5] END BAG__estimator=SVC(), BAG__n_estimators=50;, score=-3.956 total time=   0.1s
# [CV 3/5] END BAG__estimator=SVC(), BAG__n_estimators=50;, score=-6.458 total time=   0.1s
# [CV 4/5] END BAG__estimator=SVC(), BAG__n_estimators=50;, score=-5.411 total time=   0.1s
# [CV 5/5] END BAG__estimator=SVC(), BAG__n_estimators=50;, score=-4.529 total time=   0.1s
# [CV 1/5] END BAG__estimator=SVC(), BAG__n_estimators=100;, score=-4.260 total time=   0.3s
# [CV 2/5] END BAG__estimator=SVC(), BAG__n_estimators=100;, score=-3.937 total time=   0.2s
# [CV 3/5] END BAG__estimator=SVC(), BAG__n_estimators=100;, score=-6.446 total time=   0.2s
# [CV 4/5] END BAG__estimator=SVC(), BAG__n_estimators=100;, score=-5.475 total time=   0.3s
# [CV 5/5] END BAG__estimator=SVC(), BAG__n_estimators=100;, score=-4.439 total time=   0.3s
# [CV 1/5] END BAG__estimator=LogisticRegression(), BAG__n_estimators=10;, score=-1.152 total time=   0.0s
# [CV 2/5] END BAG__estimator=LogisticRegression(), BAG__n_estimators=10;, score=-1.002 total time=   0.0s
# [CV 3/5] END BAG__estimator=LogisticRegression(), BAG__n_estimators=10;, score=-1.077 total time=   0.0s
# [CV 4/5] END BAG__estimator=LogisticRegression(), BAG__n_estimators=10;, score=-1.172 total time=   0.0s
# [CV 5/5] END BAG__estimator=LogisticRegression(), BAG__n_estimators=10;, score=-1.219 total time=   0.0s
# [CV 1/5] END BAG__estimator=LogisticRegression(), BAG__n_estimators=50;, score=-1.153 total time=   0.5s
# [CV 2/5] END BAG__estimator=LogisticRegression(), BAG__n_estimators=50;, score=-1.007 total time=   0.6s
# [CV 3/5] END BAG__estimator=LogisticRegression(), BAG__n_estimators=50;, score=-1.075 total time=   0.4s
# [CV 4/5] END BAG__estimator=LogisticRegression(), BAG__n_estimators=50;, score=-1.166 total time=   0.4s
# [CV 5/5] END BAG__estimator=LogisticRegression(), BAG__n_estimators=50;, score=-1.208 total time=   0.4s
# [CV 1/5] END BAG__estimator=LogisticRegression(), BAG__n_estimators=100;, score=-1.160 total time=   0.9s
# [CV 2/5] END BAG__estimator=LogisticRegression(), BAG__n_estimators=100;, score=-1.009 total time=   0.9s
# [CV 3/5] END BAG__estimator=LogisticRegression(), BAG__n_estimators=100;, score=-1.074 total time=   0.9s
# [CV 4/5] END BAG__estimator=LogisticRegression(), BAG__n_estimators=100;, score=-1.172 total time=   0.9s
# [CV 5/5] END BAG__estimator=LogisticRegression(), BAG__n_estimators=100;, score=-1.206 total time=   0.9s
# [CV 1/5] END BAG__estimator=DecisionTreeClassifier(), BAG__n_estimators=10;, score=-2.928 total time=   0.0s
# [CV 2/5] END BAG__estimator=DecisionTreeClassifier(), BAG__n_estimators=10;, score=-0.535 total time=   0.0s
# [CV 3/5] END BAG__estimator=DecisionTreeClassifier(), BAG__n_estimators=10;, score=-1.891 total time=   0.0s
# [CV 4/5] END BAG__estimator=DecisionTreeClassifier(), BAG__n_estimators=10;, score=-0.743 total time=   0.0s
# [CV 5/5] END BAG__estimator=DecisionTreeClassifier(), BAG__n_estimators=10;, score=-1.896 total time=   0.0s
# [CV 1/5] END BAG__estimator=DecisionTreeClassifier(), BAG__n_estimators=50;, score=-2.914 total time=   0.0s
# [CV 2/5] END BAG__estimator=DecisionTreeClassifier(), BAG__n_estimators=50;, score=-0.497 total time=   0.0s
# [CV 3/5] END BAG__estimator=DecisionTreeClassifier(), BAG__n_estimators=50;, score=-0.758 total time=   0.0s
# [CV 4/5] END BAG__estimator=DecisionTreeClassifier(), BAG__n_estimators=50;, score=-0.817 total time=   0.0s
# [CV 5/5] END BAG__estimator=DecisionTreeClassifier(), BAG__n_estimators=50;, score=-0.755 total time=   0.0s
# [CV 1/5] END BAG__estimator=DecisionTreeClassifier(), BAG__n_estimators=100;, score=-0.817 total time=   0.2s
# [CV 2/5] END BAG__estimator=DecisionTreeClassifier(), BAG__n_estimators=100;, score=-0.521 total time=   0.2s
# [CV 3/5] END BAG__estimator=DecisionTreeClassifier(), BAG__n_estimators=100;, score=-0.771 total time=   0.2s
# [CV 4/5] END BAG__estimator=DecisionTreeClassifier(), BAG__n_estimators=100;, score=-0.779 total time=   0.2s
# [CV 5/5] END BAG__estimator=DecisionTreeClassifier(), BAG__n_estimators=100;, score=-0.824 total time=   0.2s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=24, shuffle=True),
#              estimator=Pipeline(steps=[('OHE',
#                                         ColumnTransformer(transformers=[('passthrough',
#                                                                          'passthrough',
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x0000027CC9511010>),
#                                                                         ('onehotencoder',
#                                                                          OneHotEncoder(drop='first',
#                                                                                        handle_unknown='ignore',
#                                                                                        sparse_output=False),
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x0000027CC9510140>)],
#                                                           verbose_feature_names_out=False)),
#                                        ('SCL', MinMaxScaler()),
#                                        ('BAG',
#                                         BaggingClassifier(random_state=24))]),
#              param_grid={'BAG__estimator': [SVC(), LogisticRegression(),
#                                             DecisionTreeClassifier()],
#                          'BAG__n_estimators': [10, 50, 100]},
#              scoring='neg_log_loss', verbose=3)

# %%
gcv.best_params_
# Out:
# {'BAG__estimator': DecisionTreeClassifier(), 'BAG__n_estimators': 100}

# %%
gcv.best_score_
# Out:
# -0.7425134701047924

# %%
# Trying different parameters of individual models
kfold = StratifiedKFold(n_splits = 5, 
                        shuffle=True, 
                        random_state=24)



dtc = DecisionTreeClassifier()

bagg = BaggingClassifier(estimator = dtc, 
                         random_state = 24)

params = {
    'n_estimators' : [10, 50, 75],
         'estimator__max_depth' : [None, 3],
         'estimator__min_samples_split' : [2, 10],
         'estimator__min_samples_leaf' : [1, 10]}

gcv = GridSearchCV(bagg, 
                   param_grid=params, 
                   cv=kfold, 
                   scoring='neg_log_loss', 
                  verbose = 3)

# %%
gcv.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=10;, score=-2.933 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=10;, score=-0.535 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=10;, score=-1.888 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=10;, score=-0.743 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=10;, score=-1.896 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=-2.914 total time=   0.1s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=-0.494 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=-0.761 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=-0.815 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=-0.755 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=75;, score=-0.819 total time=   0.1s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=75;, score=-0.490 total time=   0.1s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=75;, score=-0.776 total time=   0.1s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=75;, score=-0.773 total time=   0.1s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=75;, score=-0.799 total time=   0.1s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=10;, score=-2.959 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=10;, score=-0.640 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=10;, score=-0.893 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=10;, score=-0.863 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=10;, score=-0.865 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=-0.812 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=-0.576 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=-0.872 total time=   0.1s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=-0.833 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=-0.862 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=75;, score=-0.823 total time=   0.1s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=75;, score=-0.592 total time=   0.1s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=75;, score=-0.881 total time=   0.1s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=75;, score=-0.852 total time=   0.1s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=75;, score=-0.875 total time=   0.1s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=10;, score=-0.970 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=10;, score=-0.859 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=10;, score=-1.172 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=10;, score=-0.995 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=10;, score=-0.876 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=-0.938 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=-0.797 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=-1.027 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=-0.968 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=-0.887 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=75;, score=-0.958 total time=   0.1s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=75;, score=-0.792 total time=   0.1s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=75;, score=-1.033 total time=   0.1s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=75;, score=-0.979 total time=   0.1s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=75;, score=-0.892 total time=   0.1s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=10;, score=-0.970 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=10;, score=-0.859 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=10;, score=-1.172 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=10;, score=-0.995 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=10;, score=-0.876 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=-0.938 total time=   0.0s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=-0.797 total time=   0.0s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=-1.027 total time=   0.0s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=-0.968 total time=   0.0s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=-0.887 total time=   0.0s
# [CV 1/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=75;, score=-0.958 total time=   0.1s
# [CV 2/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=75;, score=-0.792 total time=   0.1s
# [CV 3/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=75;, score=-1.033 total time=   0.1s
# [CV 4/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=75;, score=-0.979 total time=   0.1s
# [CV 5/5] END estimator__max_depth=None, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=75;, score=-0.892 total time=   0.1s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=10;, score=-2.153 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=10;, score=-0.812 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=10;, score=-0.992 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=10;, score=-0.868 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=10;, score=-0.849 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=-0.961 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=-0.695 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=-0.935 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=-0.864 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=50;, score=-0.842 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=75;, score=-0.984 total time=   0.1s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=75;, score=-0.716 total time=   0.1s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=75;, score=-0.964 total time=   0.1s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=75;, score=-0.865 total time=   0.1s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=2, n_estimators=75;, score=-0.855 total time=   0.1s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=10;, score=-2.153 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=10;, score=-0.817 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=10;, score=-0.995 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=10;, score=-0.884 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=10;, score=-0.851 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=-0.963 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=-0.706 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=-0.956 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=-0.880 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=50;, score=-0.844 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=75;, score=-0.983 total time=   0.1s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=75;, score=-0.726 total time=   0.1s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=75;, score=-0.983 total time=   0.1s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=75;, score=-0.881 total time=   0.1s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=1, estimator__min_samples_split=10, n_estimators=75;, score=-0.858 total time=   0.1s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=10;, score=-0.979 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=10;, score=-0.895 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=10;, score=-1.191 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=10;, score=-1.003 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=10;, score=-0.887 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=-0.946 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=-0.801 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=-1.032 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=-0.982 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=50;, score=-0.901 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=75;, score=-0.962 total time=   0.1s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=75;, score=-0.805 total time=   0.1s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=75;, score=-1.037 total time=   0.1s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=75;, score=-0.994 total time=   0.1s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=2, n_estimators=75;, score=-0.908 total time=   0.1s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=10;, score=-0.979 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=10;, score=-0.895 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=10;, score=-1.191 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=10;, score=-1.003 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=10;, score=-0.887 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=-0.946 total time=   0.0s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=-0.801 total time=   0.0s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=-1.032 total time=   0.0s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=-0.982 total time=   0.0s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=50;, score=-0.901 total time=   0.0s
# [CV 1/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=75;, score=-0.962 total time=   0.1s
# [CV 2/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=75;, score=-0.805 total time=   0.1s
# [CV 3/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=75;, score=-1.037 total time=   0.1s
# [CV 4/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=75;, score=-0.994 total time=   0.1s
# [CV 5/5] END estimator__max_depth=3, estimator__min_samples_leaf=10, estimator__min_samples_split=10, n_estimators=75;, score=-0.908 total time=   0.1s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=24, shuffle=True),
#              estimator=BaggingClassifier(estimator=DecisionTreeClassifier(),
#                                          random_state=24),
#              param_grid={'estimator__max_depth': [None, 3],
#                          'estimator__min_samples_leaf': [1, 10],
#                          'estimator__min_samples_split': [2, 10],
#                          'n_estimators': [10, 50, 75]},
#              scoring='neg_log_loss', verbose=3)

# %%
gcv.best_score_
# Out:
# -0.7312731358992163

# %%
gcv.best_params_
# Out:
# {'estimator__max_depth': None,
#  'estimator__min_samples_leaf': 1,
#  'estimator__min_samples_split': 2,
#  'n_estimators': 75}

# %%
# Trying different parameters of individual models
kfold = StratifiedKFold(n_splits = 5, 
                        shuffle=True, 
                        random_state=24)



svm = SVC(probability = True)

bagg = BaggingClassifier(estimator = svm, 
                         random_state = 24)

params = {
    'n_estimators' : [10, 50, 100],
         'estimator__C' : np.linspace(0.001, 3, 5)}

gcv = GridSearchCV(bagg, 
                   param_grid=params, 
                   cv=kfold, 
                   scoring='neg_log_loss', 
                  verbose = 3)

# %%
gcv.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END estimator__C=0.001, n_estimators=10;, score=-1.111 total time=   0.0s
# [CV 2/5] END estimator__C=0.001, n_estimators=10;, score=-1.111 total time=   0.0s
# [CV 3/5] END estimator__C=0.001, n_estimators=10;, score=-1.134 total time=   0.0s
# [CV 4/5] END estimator__C=0.001, n_estimators=10;, score=-1.217 total time=   0.0s
# [CV 5/5] END estimator__C=0.001, n_estimators=10;, score=-1.197 total time=   0.0s
# [CV 1/5] END .estimator__C=0.001, n_estimators=50;, score=nan total time=   0.2s
# [CV 2/5] END estimator__C=0.001, n_estimators=50;, score=-1.130 total time=   0.2s
# [CV 3/5] END estimator__C=0.001, n_estimators=50;, score=-1.139 total time=   0.2s
# [CV 4/5] END estimator__C=0.001, n_estimators=50;, score=-1.226 total time=   0.2s
# [CV 5/5] END .estimator__C=0.001, n_estimators=50;, score=nan total time=   0.2s
# [CV 1/5] END estimator__C=0.001, n_estimators=100;, score=nan total time=   0.5s
# [CV 2/5] END estimator__C=0.001, n_estimators=100;, score=-1.134 total time=   0.5s
# [CV 3/5] END estimator__C=0.001, n_estimators=100;, score=-1.138 total time=   0.5s
# [CV 4/5] END estimator__C=0.001, n_estimators=100;, score=nan total time=   0.5s
# [CV 5/5] END estimator__C=0.001, n_estimators=100;, score=nan total time=   0.5s
# [CV 1/5] END estimator__C=0.75075, n_estimators=10;, score=-1.061 total time=   0.0s
# [CV 2/5] END estimator__C=0.75075, n_estimators=10;, score=-1.040 total time=   0.0s
# [CV 3/5] END estimator__C=0.75075, n_estimators=10;, score=-1.080 total time=   0.0s
# [CV 4/5] END estimator__C=0.75075, n_estimators=10;, score=-1.147 total time=   0.0s
# [CV 5/5] END estimator__C=0.75075, n_estimators=10;, score=-1.108 total time=   0.0s
# [CV 1/5] END estimator__C=0.75075, n_estimators=50;, score=nan total time=   0.2s
# [CV 2/5] END estimator__C=0.75075, n_estimators=50;, score=-1.068 total time=   0.2s
# [CV 3/5] END estimator__C=0.75075, n_estimators=50;, score=-1.087 total time=   0.2s
# [CV 4/5] END estimator__C=0.75075, n_estimators=50;, score=-1.155 total time=   0.2s
# [CV 5/5] END estimator__C=0.75075, n_estimators=50;, score=nan total time=   0.3s
# [CV 1/5] END estimator__C=0.75075, n_estimators=100;, score=nan total time=   0.5s
# [CV 2/5] END estimator__C=0.75075, n_estimators=100;, score=-1.069 total time=   0.5s
# [CV 3/5] END estimator__C=0.75075, n_estimators=100;, score=-1.084 total time=   0.5s
# [CV 4/5] END estimator__C=0.75075, n_estimators=100;, score=nan total time=   0.5s
# [CV 5/5] END estimator__C=0.75075, n_estimators=100;, score=nan total time=   0.6s
# [CV 1/5] END estimator__C=1.5005, n_estimators=10;, score=-1.058 total time=   0.0s
# [CV 2/5] END estimator__C=1.5005, n_estimators=10;, score=-1.042 total time=   0.0s
# [CV 3/5] END estimator__C=1.5005, n_estimators=10;, score=-1.069 total time=   0.0s
# [CV 4/5] END estimator__C=1.5005, n_estimators=10;, score=-1.152 total time=   0.0s
# [CV 5/5] END estimator__C=1.5005, n_estimators=10;, score=-1.115 total time=   0.0s
# [CV 1/5] END estimator__C=1.5005, n_estimators=50;, score=nan total time=   0.2s
# [CV 2/5] END estimator__C=1.5005, n_estimators=50;, score=-1.067 total time=   0.2s
# [CV 3/5] END estimator__C=1.5005, n_estimators=50;, score=-1.084 total time=   0.2s
# [CV 4/5] END estimator__C=1.5005, n_estimators=50;, score=-1.152 total time=   0.2s
# [CV 5/5] END estimator__C=1.5005, n_estimators=50;, score=nan total time=   0.2s
# [CV 1/5] END estimator__C=1.5005, n_estimators=100;, score=nan total time=   0.5s
# [CV 2/5] END estimator__C=1.5005, n_estimators=100;, score=-1.067 total time=   0.5s
# [CV 3/5] END estimator__C=1.5005, n_estimators=100;, score=-1.081 total time=   0.5s
# [CV 4/5] END estimator__C=1.5005, n_estimators=100;, score=nan total time=   0.5s
# [CV 5/5] END estimator__C=1.5005, n_estimators=100;, score=nan total time=   0.5s
# [CV 1/5] END estimator__C=2.25025, n_estimators=10;, score=-1.061 total time=   0.0s
# [CV 2/5] END estimator__C=2.25025, n_estimators=10;, score=-1.042 total time=   0.0s
# [CV 3/5] END estimator__C=2.25025, n_estimators=10;, score=-1.063 total time=   0.0s
# [CV 4/5] END estimator__C=2.25025, n_estimators=10;, score=-1.153 total time=   0.0s
# [CV 5/5] END estimator__C=2.25025, n_estimators=10;, score=-1.119 total time=   0.0s
# [CV 1/5] END estimator__C=2.25025, n_estimators=50;, score=nan total time=   0.3s
# [CV 2/5] END estimator__C=2.25025, n_estimators=50;, score=-1.068 total time=   0.3s
# [CV 3/5] END estimator__C=2.25025, n_estimators=50;, score=-1.083 total time=   0.3s
# [CV 4/5] END estimator__C=2.25025, n_estimators=50;, score=-1.151 total time=   0.2s
# [CV 5/5] END estimator__C=2.25025, n_estimators=50;, score=nan total time=   0.2s
# [CV 1/5] END estimator__C=2.25025, n_estimators=100;, score=nan total time=   0.5s
# [CV 2/5] END estimator__C=2.25025, n_estimators=100;, score=-1.068 total time=   0.6s
# [CV 3/5] END estimator__C=2.25025, n_estimators=100;, score=-1.080 total time=   0.5s
# [CV 4/5] END estimator__C=2.25025, n_estimators=100;, score=nan total time=   0.5s
# [CV 5/5] END estimator__C=2.25025, n_estimators=100;, score=nan total time=   0.5s
# [CV 1/5] END estimator__C=3.0, n_estimators=10;, score=-1.058 total time=   0.0s
# [CV 2/5] END estimator__C=3.0, n_estimators=10;, score=-1.043 total time=   0.0s
# [CV 3/5] END estimator__C=3.0, n_estimators=10;, score=-1.074 total time=   0.0s
# [CV 4/5] END estimator__C=3.0, n_estimators=10;, score=-1.148 total time=   0.0s
# [CV 5/5] END estimator__C=3.0, n_estimators=10;, score=-1.120 total time=   0.0s
# [CV 1/5] END ...estimator__C=3.0, n_estimators=50;, score=nan total time=   0.2s
# [CV 2/5] END estimator__C=3.0, n_estimators=50;, score=-1.067 total time=   0.3s
# [CV 3/5] END estimator__C=3.0, n_estimators=50;, score=-1.085 total time=   0.2s
# [CV 4/5] END estimator__C=3.0, n_estimators=50;, score=-1.148 total time=   0.2s
# [CV 5/5] END ...estimator__C=3.0, n_estimators=50;, score=nan total time=   0.2s
# [CV 1/5] END ..estimator__C=3.0, n_estimators=100;, score=nan total time=   0.5s
# [CV 2/5] END estimator__C=3.0, n_estimators=100;, score=-1.068 total time=   0.6s
# [CV 3/5] END estimator__C=3.0, n_estimators=100;, score=-1.082 total time=   0.5s
# [CV 4/5] END ..estimator__C=3.0, n_estimators=100;, score=nan total time=   0.6s
# [CV 5/5] END ..estimator__C=3.0, n_estimators=100;, score=nan total time=   0.5s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=24, shuffle=True),
#              estimator=BaggingClassifier(estimator=SVC(probability=True),
#                                          random_state=24),
#              param_grid={'estimator__C': array([1.00000e-03, 7.50750e-01, 1.50050e+00, 2.25025e+00, 3.00000e+00]),
#                          'n_estimators': [10, 50, 100]},
#              scoring='neg_log_loss', verbose=3)

# %%
gcv.best_score_
# Out:
# -1.087130220471035

# %%
gcv.best_params_
# Out:
# {'estimator__C': 1.5005, 'n_estimators': 10}
